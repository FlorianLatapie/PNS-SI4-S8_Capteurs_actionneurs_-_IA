# %% [markdown]
# # Lab 1 Part II: UCI-HAR 1D CNN

# %% [markdown]
# ## Imports

# %%
from pathlib import Path
import numpy as np
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Input, Conv1D, MaxPool1D, Flatten, Dense, Activation
from keras.utils.data_utils import get_file
from keras.utils.np_utils import to_categorical
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load and format UCI-HAR dataset (raw data)

# %%
dataset_path = get_file(None, "https://archive.ics.uci.edu/ml/machine-learning-databases/00240/UCI%20HAR%20Dataset.zip", extract=True, file_hash="53e099237392e0b9602f8c38f578bd8f") # Download, cache and extract UCI-HAR
dataset_dir = Path(dataset_path).parent

def load_set(dataset_dir, part: str): # Load separate sensor signals and combine them into a single array, load labels separately
    data = np.hstack([np.loadtxt(dataset_dir/'UCI HAR Dataset'/part/'Inertial Signals'/f'{sensor}_{axis}_{part}.txt')
                for sensor in ('body_acc', 'body_gyro', 'total_acc')
                    for axis in ('x', 'y', 'z')]).reshape((-1, 128, 9))
    labels = to_categorical(np.loadtxt(dataset_dir/'UCI HAR Dataset'/part/f'y_{part}.txt') - 1)
    return data, labels

x_train, y_train = load_set(dataset_dir, 'train')
x_test, y_test = load_set(dataset_dir, 'test')

# %% [markdown]
# ## Export complete test dataset (2947 vectors)

# %%
np.savetxt('x_test_uci-har.csv', x_test.reshape((x_test.shape[0], -1)), delimiter=',', fmt='%s')
np.savetxt('y_test_uci-har.csv', y_test, delimiter=',', fmt='%s')

# %% [markdown]
# ## Export small test dataset (250 vectors)

# %%
x_test_250 = x_test[0:250]
y_test_250 = y_test[0:250]
np.savetxt('x_test_uci-har_250.csv', x_test_250.reshape((x_test_250.shape[0], -1)), delimiter=',', fmt='%s')
np.savetxt('y_test_uci-har_250.csv', y_test_250, delimiter=',', fmt='%s')

# %% [markdown]
# ## Build model

# %%
model = Sequential()
model.add(Input(shape=(128, 9)))
model.add(Conv1D(filters=10, kernel_size=7, activation='relu'))
model.add(MaxPool1D())
model.add(Conv1D(filters=10, kernel_size=11, activation='relu'))
model.add(Flatten())
model.add(Dense(units=6))
model.add(Activation('softmax')) # SoftMax activation needs to be separate from Dense to remove it later on
# EXPLORE Learning Rate
opt = tf.keras.optimizers.Adam(learning_rate=10e-3)
model.summary()
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_5 (Conv1D)           (None, 122, 10)           640
#
#  max_pooling1d_3 (MaxPooling  (None, 61, 10)           0
#  1D)
#
#  conv1d_6 (Conv1D)           (None, 51, 10)            1110
#
#  max_pooling1d_4 (MaxPooling  (None, 25, 10)           0
#  1D)
#
#  conv1d_7 (Conv1D)           (None, 19, 10)            710
#
#  flatten_2 (Flatten)         (None, 190)               0
#
#  dense_2 (Dense)             (None, 6)                 1146
#
#  activation_2 (Activation)   (None, 6)                 0
#
# =================================================================
# Total params: 3,606
# Trainable params: 3,606
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Train model

# %%
history = model.fit(x_train, y_train, epochs=30, validation_data=(x_test, y_test))

plt.plot(history.history['categorical_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.show()


plt.plot(history.history['loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.show()
# Out:
# Epoch 1/30
# 230/230 [==============================] - 1s 5ms/step - loss: 0.3283 - categorical_accuracy: 0.9649 - val_loss: 2.1855 - val_categorical_accuracy: 0.9158
# Epoch 2/30
# 230/230 [==============================] - 1s 5ms/step - loss: 0.1437 - categorical_accuracy: 0.9750 - val_loss: 1.6191 - val_categorical_accuracy: 0.9260
# Epoch 3/30
# 230/230 [==============================] - 1s 5ms/step - loss: 0.1562 - categorical_accuracy: 0.9732 - val_loss: 1.3579 - val_categorical_accuracy: 0.9332
# Epoch 4/30
# 230/230 [==============================] - 1s 5ms/step - loss: 0.0766 - categorical_accuracy: 0.9818 - val_loss: 1.4787 - val_categorical_accuracy: 0.9355
# Epoch 5/30
# 230/230 [==============================] - 1s 4ms/step - loss: 0.0442 - categorical_accuracy: 0.9854 - val_loss: 1.5774 - val_categorical_accuracy: 0.9321
# Epoch 6/30
# 230/230 [==============================] - 1s 4ms/step - loss: 0.0357 - categorical_accuracy: 0.9882 - val_loss: 1.5316 - val_categorical_accuracy: 0.9301
# Epoch 7/30
# 230/230 [==============================] - 1s 4ms/step - loss: 0.0848 - categorical_accuracy: 0.9826 - val_loss: 1.7952 - val_categorical_accuracy: 0.9372
# Epoch 8/30
# 230/230 [==============================] - 1s 5ms/step - loss: 0.0283 - categorical_accuracy: 0.9895 - val_loss: 1.6741 - val_categorical_accuracy: 0.9355
# Epoch 9/30
# 230/230 [==============================] - 1s 5ms/step - loss: 0.0281 - categorical_accuracy: 0.9903 - val_loss: 2.6912 - val_categorical_accuracy: 0.9260
# Epoch 10/30
# 230/230 [==============================] - 1s 5ms/step - loss: 0.3411 - categorical_accuracy: 0.9746 - val_loss: 2.1506 - val_categorical_accuracy: 0.9335
# Epoch 11/30
# 230/230 [==============================] - 1s 5ms/step - loss: 0.2131 - categorical_accuracy: 0.9720 - val_loss: 2.0396 - val_categorical_accuracy: 0.9206
# Epoch 12/30
# 230/230 [==============================] - 1s 5ms/step - loss: 0.5206 - categorical_accuracy: 0.9633 - val_loss: 4.2391 - val_categorical_accuracy: 0.8877
# Epoch 13/30
# 230/230 [==============================] - 1s 5ms/step - loss: 0.2783 - categorical_accuracy: 0.9674 - val_loss: 2.1541 - val_categorical_accuracy: 0.9345
# Epoch 14/30
# 230/230 [==============================] - 1s 5ms/step - loss: 0.1889 - categorical_accuracy: 0.9785 - val_loss: 2.3643 - val_categorical_accuracy: 0.9209
# Epoch 15/30
# 230/230 [==============================] - 1s 5ms/step - loss: 0.0926 - categorical_accuracy: 0.9799 - val_loss: 2.5360 - val_categorical_accuracy: 0.9267
# Epoch 16/30
# 230/230 [==============================] - 1s 5ms/step - loss: 0.1155 - categorical_accuracy: 0.9827 - val_loss: 2.4835 - val_categorical_accuracy: 0.9335
# Epoch 17/30
# 230/230 [==============================] - 1s 5ms/step - loss: 0.0506 - categorical_accuracy: 0.9834 - val_loss: 2.2339 - val_categorical_accuracy: 0.9291
# Epoch 18/30
# 230/230 [==============================] - 1s 5ms/step - loss: 0.0471 - categorical_accuracy: 0.9871 - val_loss: 2.1281 - val_categorical_accuracy: 0.9342
# Epoch 19/30
# 230/230 [==============================] - 1s 5ms/step - loss: 0.0453 - categorical_accuracy: 0.9861 - val_loss: 3.1525 - val_categorical_accuracy: 0.9141
# Epoch 20/30
# 230/230 [==============================] - 1s 5ms/step - loss: 0.0793 - categorical_accuracy: 0.9823 - val_loss: 3.4074 - val_categorical_accuracy: 0.9243
# Epoch 21/30
# 230/230 [==============================] - 1s 5ms/step - loss: 0.0627 - categorical_accuracy: 0.9834 - val_loss: 1.9815 - val_categorical_accuracy: 0.9386
# Epoch 22/30
# 230/230 [==============================] - 1s 5ms/step - loss: 0.1084 - categorical_accuracy: 0.9850 - val_loss: 3.8416 - val_categorical_accuracy: 0.9277
# Epoch 23/30
# 230/230 [==============================] - 1s 5ms/step - loss: 0.6519 - categorical_accuracy: 0.9644 - val_loss: 2.6625 - val_categorical_accuracy: 0.9237
# Epoch 24/30
# 230/230 [==============================] - 1s 5ms/step - loss: 0.3901 - categorical_accuracy: 0.9672 - val_loss: 2.3575 - val_categorical_accuracy: 0.9274
# Epoch 25/30
# 230/230 [==============================] - 1s 5ms/step - loss: 0.2152 - categorical_accuracy: 0.9747 - val_loss: 4.0235 - val_categorical_accuracy: 0.9277
# Epoch 26/30
# 230/230 [==============================] - 1s 5ms/step - loss: 0.0942 - categorical_accuracy: 0.9789 - val_loss: 2.1536 - val_categorical_accuracy: 0.9325
# Epoch 27/30
# 230/230 [==============================] - 1s 5ms/step - loss: 0.0925 - categorical_accuracy: 0.9797 - val_loss: 2.9371 - val_categorical_accuracy: 0.9328
# Epoch 28/30
# 230/230 [==============================] - 1s 5ms/step - loss: 0.2305 - categorical_accuracy: 0.9755 - val_loss: 3.7108 - val_categorical_accuracy: 0.9162
# Epoch 29/30
# 230/230 [==============================] - 1s 5ms/step - loss: 0.1628 - categorical_accuracy: 0.9769 - val_loss: 2.2949 - val_categorical_accuracy: 0.9359
# Epoch 30/30
# 230/230 [==============================] - 1s 5ms/step - loss: 0.0825 - categorical_accuracy: 0.9827 - val_loss: 2.5744 - val_categorical_accuracy: 0.9352

# %% [markdown]
# ## Evaluate model on complete test dataset

# %%
model.evaluate(x_test, y_test, verbose=2)
pred_test = model.predict(x_test)
print(tf.math.confusion_matrix(y_test.argmax(axis=1), pred_test.argmax(axis=1)))
# Out:
# 93/93 - 0s - loss: 2.5744 - categorical_accuracy: 0.9352 - 180ms/epoch - 2ms/step
# 93/93 [==============================] - 0s 2ms/step
# tf.Tensor(
# [[481   7   7   0   1   0]
#  [  6 458   4   2   0   1]
#  [ 12  29 379   0   0   0]
#  [  0   1   0 421  64   5]
#  [  3   2   0  45 481   1]
#  [  0   0   0   1   0 536]], shape=(6, 6), dtype=int32)

# %% [markdown]
# ## Evaluate model on small test dataset

# %%
model.evaluate(x_test_250, y_test_250, verbose=2)
pred_test_250 = model.predict(x_test_250)
print(tf.math.confusion_matrix(y_test_250.argmax(axis=1), pred_test_250.argmax(axis=1)))
# Out:
# 8/8 - 0s - loss: 3.2113 - categorical_accuracy: 0.8760 - 30ms/epoch - 4ms/step
# 8/8 [==============================] - 0s 2ms/step
# tf.Tensor(
# [[53  0  0  0  0  0]
#  [ 0 25  0  0  0  0]
#  [ 2  7 15  0  0  0]
#  [ 0  0  0 25 21  0]
#  [ 0  0  0  1 53  0]
#  [ 0  0  0  0  0 48]], shape=(6, 6), dtype=int32)

# %% [markdown]
# ## Save trained model

# %%
model.save('lab1_part2_uci-har.h5')
