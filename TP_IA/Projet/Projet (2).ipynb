# %% [markdown]
# # Projet

# %% [markdown]
# ## Imports

# %%
import copy
import wave
from pathlib import Path
import numpy as np
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Input, Conv1D, AvgPool1D, MaxPool1D, ZeroPadding1D, BatchNormalization, Flatten, Dense, Activation
from keras.utils.np_utils import to_categorical
import os
import requests
import librosa
import soundfile as sf

# %% [markdown]
# ## Récupération des données

# %%
def download_file(link, directory, filename):
    if os.path.exists(os.path.join(directory, filename)):
        print("File exists, skipping")
        return

    if not os.path.exists(directory):
        path = directory.split(os.sep)
        for i in range(1, len(path) + 1):
            sub_dir = os.path.join(*path[:i])
            if not os.path.exists(sub_dir):
                os.makedirs(sub_dir)

    with open(os.path.join(directory, filename), 'wb') as f:
        f.write(requests.get(link).content)
    f.close()


def get_bird_json(bird_name, recording_quality, number_of_recordings):
    api_base_link = "https://xeno-canto.org/api/2/recordings?query="
    quality_header = "q:"
    bird_name = "+".join(bird_name.split(" "))

    final_json = []

    for quality in recording_quality:
        print("Getting recordings data for", bird_name, "with quality", quality)
        api_link = api_base_link + bird_name + "+" + quality_header + quality
        json_recording = requests.get(api_link).json()["recordings"]
        final_json.extend(json_recording)

    final_json = [recording for recording in final_json if "song" in recording["type"]]
    return final_json[:number_of_recordings]


def download_from_bird_json_infos(recordings_folder, bird_json):
    len_bird_recordings = len(bird_json)
    for index, recording in enumerate(bird_json):
        print("Downloading file:", index + 1, "out of", len_bird_recordings, "(", recording["file-name"], ")")
        download_file(recording["file"], os.path.join(recordings_folder, recording["gen"] + "_" + recording["sp"]),
                      recording["q"] + "_" + recording["file-name"])

# %%
def split_audio_file(audio_file_path, output_folder, output_file_name, split_length=1):
    # if filename starts with splitted_ then skip
    if output_file_name.startswith("splitted_"):
        print("file already splitted, skipping")
        return
    if any("splitted_"+output_file_name in f for f in os.listdir(output_folder)):
        print("file already exists, skipping")
        return
    audio_signal, sample_rate = librosa.load(audio_file_path, sr=None)

    len_audio_signal = len(audio_signal)

    split_length_samples = split_length * sample_rate
    audio_signal = audio_signal[:len_audio_signal - len_audio_signal % split_length_samples]
    if len(audio_signal) > split_length:
        audio_signal = np.split(audio_signal, len(audio_signal) / split_length_samples)

    number_of_files = str(int(len_audio_signal / sample_rate))
    for index, y_split in enumerate(audio_signal):
        sf.write(
            os.path.join(output_folder,
                         "splitted_" + output_file_name + "_" + str(index + 1) + "_of_" + number_of_files + ".wav"),
            y_split, sample_rate)
    # os.remove(audio_file_path)

# %%
# parameters
main_bird = "Parus major"
main_bird_quality = ("A", "B", "C")
number_of_main_bird_recordings = 200

test_bird_1 = "Turdus merula"
test_bird_1_quality = ("A", "B", "C")
number_of_test_bird_1_recordings = 200

test_bird_2 = "Fringilla coelebs"
test_bird_2_quality = ("A", "B", "C")
number_of_test_bird_2_recordings = 200

recordings_folder = "recordings"

# dl data
main_bird_recordings_json = get_bird_json(main_bird, main_bird_quality, number_of_main_bird_recordings)
download_from_bird_json_infos(recordings_folder, main_bird_recordings_json)

test_bird_1_recordings_json = get_bird_json(test_bird_1, test_bird_1_quality, number_of_test_bird_1_recordings)
download_from_bird_json_infos(recordings_folder, test_bird_1_recordings_json)

test_bird_2_recordings_json = get_bird_json(test_bird_2, test_bird_2_quality, number_of_test_bird_2_recordings)
download_from_bird_json_infos(recordings_folder, test_bird_2_recordings_json)

# clean data

print("splitting audio into multiple recordings")
for bird_type in os.listdir(recordings_folder):
    bird_folder = os.path.join(recordings_folder, bird_type)
    print("looking into folder:", bird_folder)
    if os.path.isdir(bird_folder):
        number_of_recordings = len(os.listdir(bird_folder))
        for index, recording in enumerate(os.listdir(bird_folder)):
            print("splitting recording", str(index+1), recording, "out of", number_of_recordings, "for bird", bird_type)
            recording_path = os.path.join(bird_folder, recording)
            split_audio_file(recording_path, bird_folder, recording.split(".")[0], 3)
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# splitting recording 5447 splitted_A_XC783413-Turdus-merula_2023_78_of_375.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5448 splitted_A_XC770775-Merel-zang---Bodegraven---2022-04-03---0915-copy_108_of_707.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5449 splitted_A_XC788378-Amsel_Aichtal_20230319_1853_Gesang_6_of_70.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5450 splitted_A_XC772543-55_25_of_114.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5451 splitted_A_XC788737-turdus-merula_2023_16_of_142.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5452 splitted_A_XC787811-AMSEL,-dawn--23_106_of_1931.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5453 splitted_A_XC785469-AMSEL,-singing-in-dusk--HhWald--18_38---VOC_230311-3684_93_of_350.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5454 splitted_A_XC759431-220327-Amsel-Gesang-FH-0610-MP3_131_of_1493.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5455 splitted_A_XC770776-Merel-zang---Bodegraven---2022-05-04---0719-copy_50_of_424.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5456 splitted_A_XC759431-220327-Amsel-Gesang-FH-0610-MP3_10_of_1493.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5457 splitted_A_XC794865-blackbird_25_of_233.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5458 splitted_A_XC749119-220316 Amsel Gesang FH 0642 MP3 QA_66_of_552.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5459 splitted_A_XC770776-Merel-zang---Bodegraven---2022-05-04---0719-copy_127_of_424.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5460 splitted_A_XC787811-AMSEL,-dawn--23_69_of_1931.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5461 splitted_A_XC779952-230212_1497-tm-1511-Merel_47_of_142.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5462 splitted_A_XC787811-AMSEL,-dawn--23_116_of_1931.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5463 splitted_A_XC770775-Merel-zang---Bodegraven---2022-04-03---0915-copy_207_of_707.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5464 splitted_A_XC770777-Merel-zang---Bodegraven---2022-05-15---0832-copy_59_of_670.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5465 splitted_A_XC769212-Merel-zang---Hollum---2021-04-15---2107-copy_8_of_33.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5466 splitted_A_XC787811-AMSEL,-dawn--23_445_of_1931.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5467 splitted_A_XC770779-Merel-zang---Bodegraven---2022-05-15---0923-copy_103_of_620.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5468 splitted_A_XC770774-Merel-zang---Bodegraven---2022-04-03---0824-copy_112_of_381.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5469 splitted_A_XC787454-B_3_of_58.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5470 splitted_A_XC783413-Turdus-merula_2023_11_of_375.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5471 splitted_A_XC770775-Merel-zang---Bodegraven---2022-04-03---0915-copy_39_of_707.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5472 splitted_A_XC770779-Merel-zang---Bodegraven---2022-05-15---0923-copy_27_of_620.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5473 splitted_A_XC794533-blackbird_5_of_129.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5474 splitted_A_XC769851-45_24_of_100.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5475 splitted_A_XC787385-230321_04Turdus-merula-7_21_of_198.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5476 splitted_A_XC749119-220316 Amsel Gesang FH 0642 MP3 QA_54_of_552.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5477 splitted_A_XC779952-230212_1497-tm-1511-Merel_28_of_142.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5478 splitted_A_XC759431-220327-Amsel-Gesang-FH-0610-MP3_401_of_1493.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5479 splitted_A_XC769854-47_4_of_114.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5480 splitted_A_XC784705-230306_10Turdus-merula-17_56_of_198.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5481 splitted_A_XC769856-49_30_of_182.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5482 splitted_A_XC770773-Merel-zang---Bodegraven---2022-03-30---0633-copy_195_of_726.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5483 splitted_A_XC788931-merel_ochtend_3_of_133.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5484 splitted_A_XC787146-S_TURMER_230319-0619_1_21_of_82.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5485 splitted_A_XC783413-Turdus-merula_2023_20_of_375.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5486 splitted_A_XC770776-Merel-zang---Bodegraven---2022-05-04---0719-copy_37_of_424.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5487 splitted_A_XC770773-Merel-zang---Bodegraven---2022-03-30---0633-copy_239_of_726.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5488 splitted_A_XC786571-blackbird_43_of_283.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5489 splitted_A_XC788931-merel_ochtend_22_of_133.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5490 splitted_A_XC770773-Merel-zang---Bodegraven---2022-03-30---0633-copy_98_of_726.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5491 splitted_A_XC769861-51_28_of_117.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5492 splitted_A_XC770775-Merel-zang---Bodegraven---2022-04-03---0915-copy_133_of_707.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5493 splitted_A_XC770778-Merel-zang---Bodegraven---2022-05-15---0906-copy_46_of_513.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5494 splitted_A_XC794897-Turdus-merula_song-male_200423_Escober-de-Tabara_26_of_97.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5495 splitted_A_XC791270-220530_010_Tr1_7_of_158.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5496 splitted_A_XC789663-2022_april_02_merel_1811hrs_TorrejonElRubio_GOKeijl_17_of_105.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5497 splitted_A_XC770775-Merel-zang---Bodegraven---2022-04-03---0915-copy_144_of_707.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5498 splitted_A_XC784705-230306_10Turdus-merula-17_39_of_198.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5499 splitted_A_XC759431-220327-Amsel-Gesang-FH-0610-MP3_301_of_1493.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5500 splitted_A_XC787811-AMSEL,-dawn--23_393_of_1931.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5501 splitted_A_XC770775-Merel-zang---Bodegraven---2022-04-03---0915-copy_197_of_707.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5502 splitted_A_XC770778-Merel-zang---Bodegraven---2022-05-15---0906-copy_109_of_513.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5503 splitted_A_XC758225-Merel,-winter-zang,-IGS,-101022,-0552-uur_1_of_248.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5504 splitted_A_XC787811-AMSEL,-dawn--23_219_of_1931.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5505 splitted_A_XC787811-AMSEL,-dawn--23_296_of_1931.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5506 splitted_A_XC787811-AMSEL,-dawn--23_371_of_1931.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5507 splitted_A_XC770777-Merel-zang---Bodegraven---2022-05-15---0832-copy_190_of_670.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5508 splitted_A_XC759431-220327-Amsel-Gesang-FH-0610-MP3_279_of_1493.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5509 splitted_A_XC779952-230212_1497-tm-1511-Merel_37_of_142.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5510 splitted_A_XC783137-230228_2293-Merel_2_of_33.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5511 splitted_A_XC787580-Turdus_merula2-(mp3cut_9_of_33.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5512 splitted_A_XC770778-Merel-zang---Bodegraven---2022-05-15---0906-copy_78_of_513.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5513 splitted_A_XC770779-Merel-zang---Bodegraven---2022-05-15---0923-copy_122_of_620.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5514 splitted_A_XC787144-S_TURMER_230319-0617_1_28_of_146.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5515 splitted_A_XC759431-220327-Amsel-Gesang-FH-0610-MP3_366_of_1493.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5516 splitted_A_XC772543-55_35_of_114.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5517 splitted_A_XC786571-blackbird_89_of_283.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5518 splitted_A_XC787811-AMSEL,-dawn--23_413_of_1931.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5519 splitted_A_XC770778-Merel-zang---Bodegraven---2022-05-15---0906-copy_169_of_513.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5520 splitted_A_XC788381-Amsel_Aichtal_20230322_0527_Gesang_7_of_63.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5521 splitted_A_XC783412-Turdus-merula_2023_31_of_377.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5522 splitted_A_XC759431-220327-Amsel-Gesang-FH-0610-MP3_257_of_1493.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5523 splitted_A_XC749119-220316 Amsel Gesang FH 0642 MP3 QA_36_of_552.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5524 splitted_A_XC784706-230306_11Turdus-merula-17_37_of_147.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5525 splitted_A_XC770778-Merel-zang---Bodegraven---2022-05-15---0906-copy_74_of_513.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5526 splitted_A_XC770772-Merel-zang---Bodegraven---2022-03-28---0736-copy_3_of_197.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5527 splitted_A_XC769176-Merel-zang---Hoenderloo---2022-05-10---1808-copy_28_of_90.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5528 splitted_A_XC783413-Turdus-merula_2023_108_of_375.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5529 splitted_A_XC787811-AMSEL,-dawn--23_21_of_1931.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5530 splitted_A_XC776596-amsel_bipsiboy_garten_kristein_22012023morgen1_7_of_226.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5531 splitted_A_XC785469-AMSEL,-singing-in-dusk--HhWald--18_38---VOC_230311-3684_31_of_350.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5532 splitted_A_XC788737-turdus-merula_2023_42_of_142.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5533 splitted_A_XC785469-AMSEL,-singing-in-dusk--HhWald--18_38---VOC_230311-3684_114_of_350.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5534 splitted_A_XC787811-AMSEL,-dawn--23_120_of_1931.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5535 splitted_A_XC787454-B_2_of_58.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5536 splitted_A_XC750372-xc-wa013316-000012_12_of_58.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5537 splitted_A_XC770777-Merel-zang---Bodegraven---2022-05-15---0832-copy_60_of_670.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5538 splitted_A_XC770774-Merel-zang---Bodegraven---2022-04-03---0824-copy_6_of_381.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5539 A_XC788381-Amsel_Aichtal_20230322_0527_Gesang.wav out of 5895 for bird Turdus_merula
# file already exists, skipping
# splitting recording 5540 splitted_A_XC770775-Merel-zang---Bodegraven---2022-04-03---0915-copy_29_of_707.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5541 splitted_A_XC784705-230306_10Turdus-merula-17_58_of_198.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5542 splitted_A_XC787811-AMSEL,-dawn--23_314_of_1931.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5543 splitted_A_XC770776-Merel-zang---Bodegraven---2022-05-04---0719-copy_15_of_424.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5544 splitted_A_XC749119-220316 Amsel Gesang FH 0642 MP3 QA_122_of_552.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5545 splitted_A_XC787811-AMSEL,-dawn--23_609_of_1931.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5546 splitted_A_XC770779-Merel-zang---Bodegraven---2022-05-15---0923-copy_168_of_620.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5547 splitted_A_XC769859-50_24_of_89.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5548 splitted_A_XC749119-220316 Amsel Gesang FH 0642 MP3 QA_88_of_552.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5549 splitted_A_XC783413-Turdus-merula_2023_76_of_375.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5550 splitted_A_XC759431-220327-Amsel-Gesang-FH-0610-MP3_51_of_1493.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5551 splitted_A_XC770777-Merel-zang---Bodegraven---2022-05-15---0832-copy_17_of_670.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5552 splitted_A_XC787811-AMSEL,-dawn--23_561_of_1931.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5553 splitted_A_XC792322-Turdus-merula_SONG_Etang-de-LIndre_230408_0722_16_of_62.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5554 splitted_A_XC784705-230306_10Turdus-merula-17_17_of_198.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5555 splitted_A_XC770775-Merel-zang---Bodegraven---2022-04-03---0915-copy_81_of_707.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5556 splitted_A_XC783412-Turdus-merula_2023_110_of_377.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5557 splitted_A_XC789842-220501_001_Tr1_31_of_218.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5558 splitted_A_XC783412-Turdus-merula_2023_57_of_377.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5559 splitted_A_XC783138-230228_2310-Merel_6_of_42.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5560 splitted_A_XC770779-Merel-zang---Bodegraven---2022-05-15---0923-copy_24_of_620.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5561 splitted_A_XC759431-220327-Amsel-Gesang-FH-0610-MP3_122_of_1493.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5562 splitted_A_XC784706-230306_11Turdus-merula-17_3_of_147.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5563 splitted_A_XC759431-220327-Amsel-Gesang-FH-0610-MP3_4_of_1493.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5564 splitted_A_XC759431-220327-Amsel-Gesang-FH-0610-MP3_1_of_1493.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5565 splitted_A_XC788931-merel_ochtend_7_of_133.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5566 splitted_A_XC788734-Turdus-merula_2023_5_of_39.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5567 splitted_A_XC787811-AMSEL,-dawn--23_625_of_1931.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5568 splitted_A_XC784705-230306_10Turdus-merula-17_46_of_198.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5569 splitted_A_XC759431-220327-Amsel-Gesang-FH-0610-MP3_147_of_1493.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5570 splitted_A_XC749119-220316 Amsel Gesang FH 0642 MP3 QA_62_of_552.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5571 splitted_A_XC788931-merel_ochtend_28_of_133.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5572 splitted_A_XC787982-Solsort-(Turdus-merula)-Gludsted-Plantage_20230317-1817-sang_57_of_188.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5573 splitted_A_XC791270-220530_010_Tr1_28_of_158.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5574 splitted_A_XC770775-Merel-zang---Bodegraven---2022-04-03---0915-copy_224_of_707.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5575 splitted_A_XC770779-Merel-zang---Bodegraven---2022-05-15---0923-copy_97_of_620.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5576 splitted_A_XC786571-blackbird_62_of_283.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5577 splitted_A_XC787340-Chant-d’oiseau-Champ-merle-matin_6_of_38.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5578 splitted_A_XC783412-Turdus-merula_2023_94_of_377.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5579 splitted_A_XC759431-220327-Amsel-Gesang-FH-0610-MP3_256_of_1493.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5580 splitted_A_XC770775-Merel-zang---Bodegraven---2022-04-03---0915-copy_3_of_707.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5581 splitted_A_XC776596-amsel_bipsiboy_garten_kristein_22012023morgen1_41_of_226.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5582 splitted_A_XC770776-Merel-zang---Bodegraven---2022-05-04---0719-copy_82_of_424.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5583 splitted_A_XC770778-Merel-zang---Bodegraven---2022-05-15---0906-copy_114_of_513.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5584 splitted_A_XC770779-Merel-zang---Bodegraven---2022-05-15---0923-copy_29_of_620.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5585 splitted_A_XC785469-AMSEL,-singing-in-dusk--HhWald--18_38---VOC_230311-3684_79_of_350.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5586 splitted_A_XC791288-220531_016_Tr1_15_of_169.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5587 splitted_A_XC769859-50_4_of_89.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5588 splitted_A_XC770777-Merel-zang---Bodegraven---2022-05-15---0832-copy_65_of_670.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5589 splitted_A_XC759431-220327-Amsel-Gesang-FH-0610-MP3_411_of_1493.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5590 splitted_A_XC770777-Merel-zang---Bodegraven---2022-05-15---0832-copy_123_of_670.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5591 splitted_A_XC787146-S_TURMER_230319-0619_1_9_of_82.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5592 splitted_A_XC759431-220327-Amsel-Gesang-FH-0610-MP3_398_of_1493.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5593 splitted_A_XC759431-220327-Amsel-Gesang-FH-0610-MP3_28_of_1493.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5594 splitted_A_XC770776-Merel-zang---Bodegraven---2022-05-04---0719-copy_69_of_424.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5595 splitted_A_XC770774-Merel-zang---Bodegraven---2022-04-03---0824-copy_22_of_381.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5596 splitted_A_XC790089-220515_012_Tr1_38_of_122.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5597 splitted_A_XC783412-Turdus-merula_2023_58_of_377.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5598 splitted_A_XC787811-AMSEL,-dawn--23_277_of_1931.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5599 splitted_A_XC793974-20230417_133913-merlo-palazzi-masseria_3_of_25.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5600 splitted_A_XC779952-230212_1497-tm-1511-Merel_46_of_142.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5601 splitted_A_XC770772-Merel-zang---Bodegraven---2022-03-28---0736-copy_28_of_197.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5602 splitted_A_XC759431-220327-Amsel-Gesang-FH-0610-MP3_483_of_1493.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5603 A_XC789842-220501_001_Tr1.mp3 out of 5895 for bird Turdus_merula
# file already exists, skipping
# splitting recording 5604 splitted_A_XC770775-Merel-zang---Bodegraven---2022-04-03---0915-copy_109_of_707.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5605 splitted_A_XC784705-230306_10Turdus-merula-17_11_of_198.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5606 splitted_A_XC749119-220316 Amsel Gesang FH 0642 MP3 QA_90_of_552.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5607 splitted_A_XC787811-AMSEL,-dawn--23_306_of_1931.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5608 splitted_A_XC759976-Merel-20220522-1720-1a_33_of_113.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5609 splitted_A_XC782475-20230215_174058-merlo_39_of_174.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5610 splitted_A_XC785469-AMSEL,-singing-in-dusk--HhWald--18_38---VOC_230311-3684_35_of_350.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5611 splitted_A_XC770777-Merel-zang---Bodegraven---2022-05-15---0832-copy_199_of_670.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5612 splitted_A_XC785469-AMSEL,-singing-in-dusk--HhWald--18_38---VOC_230311-3684_32_of_350.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5613 splitted_A_XC787811-AMSEL,-dawn--23_357_of_1931.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5614 splitted_A_XC776596-amsel_bipsiboy_garten_kristein_22012023morgen1_18_of_226.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5615 splitted_A_XC792991-TURMER-2023-04-11-07-49-SIPOONKORPI-s-A_17_of_74.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5616 splitted_A_XC770774-Merel-zang---Bodegraven---2022-04-03---0824-copy_68_of_381.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5617 splitted_A_XC794865-blackbird_43_of_233.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5618 splitted_A_XC790089-220515_012_Tr1_34_of_122.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5619 splitted_A_XC792107-Turdus-merula_song_10_04_23_Parque-Villablino_6_of_89.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5620 splitted_A_XC783412-Turdus-merula_2023_3_of_377.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5621 splitted_A_XC782475-20230215_174058-merlo_11_of_174.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5622 splitted_A_XC792833-Turdus-merula_song-male_08_04_23_Villablino_21_of_116.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5623 splitted_A_XC791288-220531_016_Tr1_27_of_169.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5624 splitted_A_XC780271-blackbirdsongtacfeb232_5_of_111.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5625 splitted_A_XC783412-Turdus-merula_2023_40_of_377.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5626 splitted_A_XC770775-Merel-zang---Bodegraven---2022-04-03---0915-copy_178_of_707.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5627 splitted_A_XC770773-Merel-zang---Bodegraven---2022-03-30---0633-copy_80_of_726.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5628 splitted_A_XC789842-220501_001_Tr1_41_of_218.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5629 splitted_A_XC784706-230306_11Turdus-merula-17_31_of_147.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5630 splitted_A_XC794865-blackbird_26_of_233.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5631 splitted_A_XC784706-230306_11Turdus-merula-17_23_of_147.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5632 splitted_A_XC770775-Merel-zang---Bodegraven---2022-04-03---0915-copy_67_of_707.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5633 A_XC724072-TURMER_220513_1981_Marcevol66.mp3 out of 5895 for bird Turdus_merula
# splitting recording 5634 splitted_A_XC758225-Merel,-winter-zang,-IGS,-101022,-0552-uur_64_of_248.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5635 splitted_A_XC749119-220316 Amsel Gesang FH 0642 MP3 QA_144_of_552.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5636 splitted_A_XC770773-Merel-zang---Bodegraven---2022-03-30---0633-copy_172_of_726.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5637 splitted_A_XC770773-Merel-zang---Bodegraven---2022-03-30---0633-copy_41_of_726.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5638 splitted_A_XC759431-220327-Amsel-Gesang-FH-0610-MP3_362_of_1493.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5639 splitted_A_XC770778-Merel-zang---Bodegraven---2022-05-15---0906-copy_149_of_513.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5640 splitted_A_XC791347-220604_018_Tr1_22_of_146.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5641 splitted_A_XC759431-220327-Amsel-Gesang-FH-0610-MP3_327_of_1493.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5642 splitted_A_XC770775-Merel-zang---Bodegraven---2022-04-03---0915-copy_192_of_707.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5643 splitted_A_XC770779-Merel-zang---Bodegraven---2022-05-15---0923-copy_128_of_620.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5644 splitted_A_XC790089-220515_012_Tr1_31_of_122.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5645 splitted_A_XC787811-AMSEL,-dawn--23_508_of_1931.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5646 splitted_A_XC749119-220316 Amsel Gesang FH 0642 MP3 QA_150_of_552.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5647 splitted_A_XC793975-20230316_150905-merlo-Bertignano-_13_of_66.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5648 splitted_A_XC770777-Merel-zang---Bodegraven---2022-05-15---0832-copy_34_of_670.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5649 splitted_A_XC770778-Merel-zang---Bodegraven---2022-05-15---0906-copy_155_of_513.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5650 splitted_A_XC794140-merelzang_9_of_58.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5651 splitted_A_XC770775-Merel-zang---Bodegraven---2022-04-03---0915-copy_84_of_707.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5652 splitted_A_XC785469-AMSEL,-singing-in-dusk--HhWald--18_38---VOC_230311-3684_15_of_350.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5653 splitted_A_XC769841-43_21_of_91.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5654 splitted_A_XC770774-Merel-zang---Bodegraven---2022-04-03---0824-copy_40_of_381.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5655 splitted_A_XC783138-230228_2310-Merel_8_of_42.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5656 splitted_A_XC788379-Amsel_Aichtal_20230320_0528_Gesang_27_of_95.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5657 splitted_A_XC770779-Merel-zang---Bodegraven---2022-05-15---0923-copy_139_of_620.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5658 splitted_A_XC788379-Amsel_Aichtal_20230320_0528_Gesang_31_of_95.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5659 splitted_A_XC769843-44_23_of_73.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5660 splitted_A_XC770773-Merel-zang---Bodegraven---2022-03-30---0633-copy_6_of_726.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5661 splitted_A_XC785469-AMSEL,-singing-in-dusk--HhWald--18_38---VOC_230311-3684_26_of_350.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5662 splitted_A_XC770775-Merel-zang---Bodegraven---2022-04-03---0915-copy_126_of_707.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5663 splitted_A_XC787385-230321_04Turdus-merula-7_1_of_198.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5664 splitted_A_XC769856-49_57_of_182.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5665 splitted_A_XC758225-Merel,-winter-zang,-IGS,-101022,-0552-uur_46_of_248.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5666 splitted_A_XC787811-AMSEL,-dawn--23_102_of_1931.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5667 splitted_A_XC787811-AMSEL,-dawn--23_607_of_1931.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5668 splitted_A_XC787811-AMSEL,-dawn--23_600_of_1931.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5669 splitted_A_XC786571-blackbird_45_of_283.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5670 splitted_A_XC770776-Merel-zang---Bodegraven---2022-05-04---0719-copy_45_of_424.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5671 splitted_A_XC770778-Merel-zang---Bodegraven---2022-05-15---0906-copy_97_of_513.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5672 splitted_A_XC759431-220327-Amsel-Gesang-FH-0610-MP3_137_of_1493.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5673 splitted_A_XC785469-AMSEL,-singing-in-dusk--HhWald--18_38---VOC_230311-3684_8_of_350.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5674 splitted_A_XC770777-Merel-zang---Bodegraven---2022-05-15---0832-copy_81_of_670.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5675 splitted_A_XC791288-220531_016_Tr1_47_of_169.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5676 splitted_A_XC769861-51_17_of_117.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5677 splitted_A_XC791270-220530_010_Tr1_1_of_158.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5678 splitted_A_XC758225-Merel,-winter-zang,-IGS,-101022,-0552-uur_82_of_248.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5679 splitted_A_XC769851-45_2_of_100.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5680 splitted_A_XC749119-220316 Amsel Gesang FH 0642 MP3 QA_21_of_552.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5681 splitted_A_XC788381-Amsel_Aichtal_20230322_0527_Gesang_3_of_63.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5682 splitted_A_XC770777-Merel-zang---Bodegraven---2022-05-15---0832-copy_178_of_670.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5683 splitted_A_XC784704-230306_09-Turdus-merula-relaxed-song--17_29_of_230.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5684 splitted_A_XC787982-Solsort-(Turdus-merula)-Gludsted-Plantage_20230317-1817-sang_23_of_188.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5685 splitted_A_XC770777-Merel-zang---Bodegraven---2022-05-15---0832-copy_85_of_670.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5686 splitted_A_XC787811-AMSEL,-dawn--23_356_of_1931.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5687 splitted_A_XC785469-AMSEL,-singing-in-dusk--HhWald--18_38---VOC_230311-3684_37_of_350.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5688 splitted_A_XC789663-2022_april_02_merel_1811hrs_TorrejonElRubio_GOKeijl_9_of_105.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5689 splitted_A_XC784704-230306_09-Turdus-merula-relaxed-song--17_70_of_230.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5690 splitted_A_XC787811-AMSEL,-dawn--23_453_of_1931.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5691 splitted_A_XC794533-blackbird_1_of_129.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5692 splitted_A_XC787811-AMSEL,-dawn--23_32_of_1931.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5693 splitted_A_XC770778-Merel-zang---Bodegraven---2022-05-15---0906-copy_104_of_513.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5694 splitted_A_XC770776-Merel-zang---Bodegraven---2022-05-04---0719-copy_48_of_424.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5695 splitted_A_XC764740-221203_003_4_of_16.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5696 splitted_A_XC749119-220316 Amsel Gesang FH 0642 MP3 QA_75_of_552.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5697 splitted_A_XC784706-230306_11Turdus-merula-17_40_of_147.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5698 splitted_A_XC770779-Merel-zang---Bodegraven---2022-05-15---0923-copy_12_of_620.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5699 splitted_A_XC792107-Turdus-merula_song_10_04_23_Parque-Villablino_17_of_89.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5700 splitted_A_XC792991-TURMER-2023-04-11-07-49-SIPOONKORPI-s-A_6_of_74.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5701 A_XC784706-230306_11Turdus-merula-17.30-Xinzo,-Brión.mp3 out of 5895 for bird Turdus_merula
# file already exists, skipping
# splitting recording 5702 splitted_A_XC769882-52_5_of_174.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5703 splitted_A_XC770775-Merel-zang---Bodegraven---2022-04-03---0915-copy_94_of_707.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5704 splitted_A_XC794897-Turdus-merula_song-male_200423_Escober-de-Tabara_16_of_97.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5705 splitted_A_XC759431-220327-Amsel-Gesang-FH-0610-MP3_79_of_1493.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5706 splitted_A_XC758225-Merel,-winter-zang,-IGS,-101022,-0552-uur_2_of_248.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5707 splitted_A_XC759431-220327-Amsel-Gesang-FH-0610-MP3_364_of_1493.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5708 splitted_A_XC770773-Merel-zang---Bodegraven---2022-03-30---0633-copy_34_of_726.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5709 splitted_A_XC786571-blackbird_69_of_283.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5710 splitted_A_XC789328-Turdus-merula_2023_9_of_45.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5711 splitted_A_XC779952-230212_1497-tm-1511-Merel_16_of_142.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5712 splitted_A_XC770774-Merel-zang---Bodegraven---2022-04-03---0824-copy_43_of_381.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5713 splitted_A_XC786387-DM671522-(mp3cut_7_of_61.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5714 splitted_A_XC759431-220327-Amsel-Gesang-FH-0610-MP3_18_of_1493.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5715 splitted_A_XC769882-52_11_of_174.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5716 splitted_A_XC787811-AMSEL,-dawn--23_252_of_1931.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5717 splitted_A_XC770776-Merel-zang---Bodegraven---2022-05-04---0719-copy_83_of_424.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5718 splitted_A_XC784704-230306_09-Turdus-merula-relaxed-song--17_13_of_230.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5719 splitted_A_XC790089-220515_012_Tr1_21_of_122.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5720 splitted_A_XC769855-48_5_of_57.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5721 splitted_A_XC792089-Koltrast_35_30_of_98.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5722 splitted_A_XC770775-Merel-zang---Bodegraven---2022-04-03---0915-copy_63_of_707.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5723 splitted_A_XC786571-blackbird_74_of_283.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5724 splitted_A_XC759431-220327-Amsel-Gesang-FH-0610-MP3_192_of_1493.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5725 splitted_A_XC785469-AMSEL,-singing-in-dusk--HhWald--18_38---VOC_230311-3684_7_of_350.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5726 splitted_A_XC789456-Turdus-merula-cabrerae-(Tenerfe)---Monte-de-Las-Vueltas-(Anaga)_13_of_41.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5727 splitted_A_XC786387-DM671522-(mp3cut_13_of_61.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5728 splitted_A_XC784704-230306_09-Turdus-merula-relaxed-song--17_40_of_230.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5729 splitted_A_XC793975-20230316_150905-merlo-Bertignano-_21_of_66.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5730 splitted_A_XC784704-230306_09-Turdus-merula-relaxed-song--17_63_of_230.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5731 splitted_A_XC770779-Merel-zang---Bodegraven---2022-05-15---0923-copy_38_of_620.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5732 splitted_A_XC787811-AMSEL,-dawn--23_4_of_1931.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5733 splitted_A_XC749119-220316 Amsel Gesang FH 0642 MP3 QA_61_of_552.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5734 splitted_A_XC769882-52_29_of_174.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5735 splitted_A_XC787811-AMSEL,-dawn--23_48_of_1931.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5736 splitted_A_XC769861-51_18_of_117.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5737 splitted_A_XC788379-Amsel_Aichtal_20230320_0528_Gesang_16_of_95.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5738 splitted_A_XC770774-Merel-zang---Bodegraven---2022-04-03---0824-copy_121_of_381.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5739 splitted_A_XC783412-Turdus-merula_2023_28_of_377.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5740 splitted_A_XC787811-AMSEL,-dawn--23_248_of_1931.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5741 splitted_A_XC770774-Merel-zang---Bodegraven---2022-04-03---0824-copy_15_of_381.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5742 splitted_A_XC769859-50_1_of_89.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5743 splitted_A_XC787146-S_TURMER_230319-0619_1_14_of_82.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5744 splitted_A_XC787580-Turdus_merula2-(mp3cut_4_of_33.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5745 splitted_A_XC759431-220327-Amsel-Gesang-FH-0610-MP3_488_of_1493.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5746 splitted_A_XC794897-Turdus-merula_song-male_200423_Escober-de-Tabara_9_of_97.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5747 splitted_A_XC769212-Merel-zang---Hollum---2021-04-15---2107-copy_7_of_33.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5748 A_XC744147-Common Blackbird_hunting lodge2_DLY.mp3 out of 5895 for bird Turdus_merula
# splitting recording 5749 splitted_A_XC770775-Merel-zang---Bodegraven---2022-04-03---0915-copy_48_of_707.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# splitting recording 5750 splitted_A_XC759431-220327-Amsel-Gesang-FH-0610-MP3_492_of_1493.wav out of 5895 for bird Turdus_merula
# file already splitted, skipping
# ...
# file already splitted, skipping
# splitting recording 1995 splitted_A_XC792650-20230411_171921-cinciallegra_5_of_25.wav out of 2103 for bird Parus_major
# file already splitted, skipping
# splitting recording 1996 splitted_A_XC783340-Parus-mahor_2023_23_of_114.wav out of 2103 for bird Parus_major
# file already splitted, skipping
# splitting recording 1997 splitted_A_XC784296-Kjøttmeis-Helgøya-Elias-A_19_of_102.wav out of 2103 for bird Parus_major
# file already splitted, skipping
# splitting recording 1998 A_XC773452-KOHLMEISEN-,-Wechselgesang--23.09.2022--Schwifting--10_53--VOC_220923-3293.wav out of 2103 for bird Parus_major
# splitting recording 1999 splitted_A_XC788023-Kjøttmeis-3-XC-wav-Helgøya-Elias-A_19_of_122.wav out of 2103 for bird Parus_major
# file already splitted, skipping
# splitting recording 2000 splitted_A_XC780064-Talgoxe-skadad_6_of_49.wav out of 2103 for bird Parus_major
# file already splitted, skipping
# splitting recording 2001 splitted_A_XC780932-Parus-major_2023_7_of_83.wav out of 2103 for bird Parus_major
# file already splitted, skipping
# splitting recording 2002 splitted_A_XC790324-04022023093431_5_of_59.wav out of 2103 for bird Parus_major
# file already splitted, skipping
# splitting recording 2003 splitted_A_XC781155-pmajor_230219_kobyla_2_of_51.wav out of 2103 for bird Parus_major
# file already splitted, skipping
# splitting recording 2004 splitted_A_XC788425-Parmajbo_10_of_31.wav out of 2103 for bird Parus_major
# file already splitted, skipping
# splitting recording 2005 splitted_A_XC790474-Great-Tit大山雀-call-似警戒-2303190851-松江叶榭SHADOW_3001S12_34_of_112.wav out of 2103 for bird Parus_major
# file already splitted, skipping
# splitting recording 2006 splitted_A_XC790538-Great-Tit大山雀-call-2302260820-松江叶榭SHADOW_2955S12_8_of_102.wav out of 2103 for bird Parus_major
# file already splitted, skipping
# splitting recording 2007 splitted_A_XC779539-KOHLMEISEN,-Gesang--9_25--IMG_-230204-3460-g_5_of_54.wav out of 2103 for bird Parus_major
# file already splitted, skipping
# splitting recording 2008 splitted_A_XC785341-koolmees_drongengoed_2_of_16.wav out of 2103 for bird Parus_major
# file already splitted, skipping
# splitting recording 2009 splitted_A_XC784015-PARMAJ-s-VBO-230227_4994_17_of_104.wav out of 2103 for bird Parus_major
# file already splitted, skipping
# splitting recording 2010 splitted_A_XC792271-P_154_of_543.wav out of 2103 for bird Parus_major
# file already splitted, skipping
# splitting recording 2011 splitted_A_XC792271-P_45_of_543.wav out of 2103 for bird Parus_major
# file already splitted, skipping
# splitting recording 2012 A_XC784686-Mésange-charbonnière-mâle-Chaussins-8-mars-2023-type-rapide.mp3 out of 2103 for bird Parus_major
# file already exists, skipping
# splitting recording 2013 splitted_A_XC782693-d)Charbo%22extra%22_3_of_42.wav out of 2103 for bird Parus_major
# file already splitted, skipping
# splitting recording 2014 splitted_A_XC790453-Kjøttmeis-XC-5-kopi-Helgøya-Elias-A_13_of_119.wav out of 2103 for bird Parus_major
# file already splitted, skipping
# splitting recording 2015 splitted_A_XC791289-gt_20230223_155641_16_of_49.wav out of 2103 for bird Parus_major
# file already splitted, skipping
# splitting recording 2016 splitted_A_XC780064-Talgoxe-skadad_4_of_49.wav out of 2103 for bird Parus_major
# file already splitted, skipping
# splitting recording 2017 splitted_A_XC790463-Great-Tit大山雀-call-2303190854-松江叶榭SHADOW_3003S12_19_of_58.wav out of 2103 for bird Parus_major
# file already splitted, skipping
# splitting recording 2018 splitted_A_XC784259-STE-000-M_10_of_65.wav out of 2103 for bird Parus_major
# file already splitted, skipping
# splitting recording 2019 splitted_A_XC778753-230202_15Parus-major-18_44_of_165.wav out of 2103 for bird Parus_major
# file already splitted, skipping
# splitting recording 2020 splitted_A_XC784685-Mésange-charbonnière-mâle-Chaussins-8-mars-2023-type-lent_5_of_22.wav out of 2103 for bird Parus_major
# file already splitted, skipping
# splitting recording 2021 A_XC778471-greattittacjan23.wav out of 2103 for bird Parus_major
# splitting recording 2022 splitted_A_XC784296-Kjøttmeis-Helgøya-Elias-A_21_of_102.wav out of 2103 for bird Parus_major
# file already splitted, skipping
# splitting recording 2023 splitted_A_XC783325-Parus-major_2023_21_of_114.wav out of 2103 for bird Parus_major
# file already splitted, skipping
# splitting recording 2024 splitted_A_XC783556-MVI_5436_4_of_18.wav out of 2103 for bird Parus_major
# file already splitted, skipping
# splitting recording 2025 splitted_A_XC783325-Parus-major_2023_4_of_114.wav out of 2103 for bird Parus_major
# file already splitted, skipping
# splitting recording 2026 splitted_A_XC792271-P_35_of_543.wav out of 2103 for bird Parus_major
# file already splitted, skipping
# splitting recording 2027 splitted_A_XC788730-great-tit-xeno-canto_2_of_32.wav out of 2103 for bird Parus_major
# file already splitted, skipping
# splitting recording 2028 splitted_A_XC780649-15-02-23-(mésange-charbonnière,-chant,-Wanne)_1_of_8.wav out of 2103 for bird Parus_major
# file already splitted, skipping
# splitting recording 2029 splitted_A_XC790197-Musvit-(Parus-major)-Matr_20230326-1745-sang_1_of_47.wav out of 2103 for bird Parus_major
# file already splitted, skipping
# splitting recording 2030 splitted_A_XC787977-Kjøttmeis-Helgøya-Elias-A_24_of_109.wav out of 2103 for bird Parus_major
# file already splitted, skipping
# splitting recording 2031 splitted_A_XC785394-Kjøttmeis-XC-4-Helgøya-Elias-A_20_of_96.wav out of 2103 for bird Parus_major
# file already splitted, skipping
# splitting recording 2032 splitted_A_XC784017-PARMAJ-s-VBO-230302_4997_6_of_151.wav out of 2103 for bird Parus_major
# file already splitted, skipping
# splitting recording 2033 splitted_A_XC792271-P_181_of_543.wav out of 2103 for bird Parus_major
# file already splitted, skipping
# splitting recording 2034 splitted_A_XC788425-Parmajbo_5_of_31.wav out of 2103 for bird Parus_major
# file already splitted, skipping
# splitting recording 2035 splitted_A_XC780676-Parus-major_2023_13_of_66.wav out of 2103 for bird Parus_major
# file already splitted, skipping
# splitting recording 2036 splitted_A_XC785898-MVI_5504_16_of_61.wav out of 2103 for bird Parus_major
# file already splitted, skipping
# splitting recording 2037 splitted_A_XC792271-P_147_of_543.wav out of 2103 for bird Parus_major
# file already splitted, skipping
# splitting recording 2038 splitted_A_XC787314-Kjøttmeis-5-Helgøya-Elias-A_40_of_132.wav out of 2103 for bird Parus_major
# file already splitted, skipping
# splitting recording 2039 splitted_A_XC790463-Great-Tit大山雀-call-2303190854-松江叶榭SHADOW_3003S12_6_of_58.wav out of 2103 for bird Parus_major
# file already splitted, skipping
# splitting recording 2040 splitted_A_XC792271-P_53_of_543.wav out of 2103 for bird Parus_major
# file already splitted, skipping
# splitting recording 2041 splitted_A_XC790324-04022023093431_12_of_59.wav out of 2103 for bird Parus_major
# file already splitted, skipping
# splitting recording 2042 splitted_A_XC785412-Kjøttmeis-XC-6-Helgøya-Elias-A_12_of_95.wav out of 2103 for bird Parus_major
# file already splitted, skipping
# splitting recording 2043 splitted_A_XC782693-d)Charbo%22extra%22_10_of_42.wav out of 2103 for bird Parus_major
# file already splitted, skipping
# splitting recording 2044 splitted_A_XC790463-Great-Tit大山雀-call-2303190854-松江叶榭SHADOW_3003S12_7_of_58.wav out of 2103 for bird Parus_major
# file already splitted, skipping
# splitting recording 2045 splitted_A_XC783340-Parus-mahor_2023_20_of_114.wav out of 2103 for bird Parus_major
# file already splitted, skipping
# splitting recording 2046 splitted_A_XC783299-Parus-Major_2023_2_of_19.wav out of 2103 for bird Parus_major
# file already splitted, skipping
# splitting recording 2047 splitted_A_XC790607-Kjøttmeis-5-XC-Helgøya-Elias-A_16_of_140.wav out of 2103 for bird Parus_major
# file already splitted, skipping
# splitting recording 2048 splitted_A_XC791687-greattit_13_of_46.wav out of 2103 for bird Parus_major
# file already splitted, skipping
# splitting recording 2049 splitted_A_XC791289-gt_20230223_155641_6_of_49.wav out of 2103 for bird Parus_major
# file already splitted, skipping
# splitting recording 2050 splitted_A_XC787387-230321_06Parus-major-two-song-types-7_20_of_75.wav out of 2103 for bird Parus_major
# file already splitted, skipping
# splitting recording 2051 splitted_A_XC792271-P_40_of_543.wav out of 2103 for bird Parus_major
# file already splitted, skipping
# splitting recording 2052 splitted_A_XC785378-Kjøttmeis-XC-3-Helgøya-Elias-A_5_of_60.wav out of 2103 for bird Parus_major
# file already splitted, skipping
# splitting recording 2053 splitted_A_XC790463-Great-Tit大山雀-call-2303190854-松江叶榭SHADOW_3003S12_17_of_58.wav out of 2103 for bird Parus_major
# file already splitted, skipping
# splitting recording 2054 splitted_A_XC792271-P_87_of_543.wav out of 2103 for bird Parus_major
# file already splitted, skipping
# splitting recording 2055 splitted_A_XC790472-Great-Tit大山雀-call-2303190904-松江叶榭2303190724-松江叶榭SHADOW_2989S12_2_of_104.wav out of 2103 for bird Parus_major
# file already splitted, skipping
# splitting recording 2056 splitted_A_XC783325-Parus-major_2023_19_of_114.wav out of 2103 for bird Parus_major
# file already splitted, skipping
# splitting recording 2057 splitted_A_XC787428-Parus-major_male-song_21_03_23_Tábara_6_of_77.wav out of 2103 for bird Parus_major
# file already splitted, skipping
# splitting recording 2058 splitted_A_XC790541-Great-Tit大山雀-call-ABCA-2301270737-松江叶榭SHADOW_2873S12_5_of_17.wav out of 2103 for bird Parus_major
# file already splitted, skipping
# splitting recording 2059 splitted_A_XC791290-gt1_20230223_155641_3_of_34.wav out of 2103 for bird Parus_major
# file already splitted, skipping
# splitting recording 2060 A_XC794645-MVI_5842.mp3 out of 2103 for bird Parus_major
# file already exists, skipping
# splitting recording 2061 splitted_A_XC787314-Kjøttmeis-5-Helgøya-Elias-A_26_of_132.wav out of 2103 for bird Parus_major
# file already splitted, skipping
# splitting recording 2062 A_XC732025-Tit_Great2_SDMKH-368_EdensGardenForestEdge_Dawn_6thJune22.mp3 out of 2103 for bird Parus_major
# splitting recording 2063 splitted_A_XC783325-Parus-major_2023_34_of_114.wav out of 2103 for bird Parus_major
# file already splitted, skipping
# splitting recording 2064 splitted_A_XC784259-STE-000-M_15_of_65.wav out of 2103 for bird Parus_major
# file already splitted, skipping
# splitting recording 2065 splitted_A_XC778753-230202_15Parus-major-18_53_of_165.wav out of 2103 for bird Parus_major
# file already splitted, skipping
# splitting recording 2066 splitted_A_XC790097-Kjøttmeis-1-Helgøya-Elias-A_29_of_156.wav out of 2103 for bird Parus_major
# file already splitted, skipping
# splitting recording 2067 splitted_A_XC784401-06-03-2023-(mésange-charbonnière,-chant,-fagne-de-Brackvenn)_3_of_38.wav out of 2103 for bird Parus_major
# file already splitted, skipping
# splitting recording 2068 splitted_A_XC783554-MVI_5425_9_of_32.wav out of 2103 for bird Parus_major
# file already splitted, skipping
# splitting recording 2069 splitted_A_XC790421-Great-Tit大山雀-call-子规x8-2304010606-动物园SHADOW_3048S12_7_of_108.wav out of 2103 for bird Parus_major
# file already splitted, skipping
# splitting recording 2070 splitted_A_XC788730-great-tit-xeno-canto_7_of_32.wav out of 2103 for bird Parus_major
# file already splitted, skipping
# splitting recording 2071 splitted_A_XC784017-PARMAJ-s-VBO-230302_4997_43_of_151.wav out of 2103 for bird Parus_major
# file already splitted, skipping
# splitting recording 2072 A_XC777118-180506_1339-0930-Mammendorf_NNP_Great-Tit.wav out of 2103 for bird Parus_major
# splitting recording 2073 splitted_A_XC790541-Great-Tit大山雀-call-ABCA-2301270737-松江叶榭SHADOW_2873S12_1_of_17.wav out of 2103 for bird Parus_major
# file already splitted, skipping
# splitting recording 2074 A_XC737812-1122 Koolmeeszang coolhem.mp3 out of 2103 for bird Parus_major
# splitting recording 2075 A_XC783299-Parus-Major_2023.01.19_09.50_02.mp3 out of 2103 for bird Parus_major
# file already exists, skipping
# splitting recording 2076 splitted_A_XC780042-PJ_Stolec_230207_02_1_of_13.wav out of 2103 for bird Parus_major
# file already splitted, skipping
# splitting recording 2077 splitted_A_XC783554-MVI_5425_10_of_32.wav out of 2103 for bird Parus_major
# file already splitted, skipping
# splitting recording 2078 splitted_A_XC780676-Parus-major_2023_22_of_66.wav out of 2103 for bird Parus_major
# file already splitted, skipping
# splitting recording 2079 splitted_A_XC781162-koolmees_3_of_29.wav out of 2103 for bird Parus_major
# file already splitted, skipping
# splitting recording 2080 splitted_A_XC783325-Parus-major_2023_18_of_114.wav out of 2103 for bird Parus_major
# file already splitted, skipping
# splitting recording 2081 splitted_A_XC790421-Great-Tit大山雀-call-子规x8-2304010606-动物园SHADOW_3048S12_26_of_108.wav out of 2103 for bird Parus_major
# file already splitted, skipping
# splitting recording 2082 splitted_A_XC788098-24-03-23-(mésange-charbonnière,-chant,-Wanne)_11_of_33.wav out of 2103 for bird Parus_major
# file already splitted, skipping
# splitting recording 2083 splitted_A_XC784015-PARMAJ-s-VBO-230227_4994_14_of_104.wav out of 2103 for bird Parus_major
# file already splitted, skipping
# splitting recording 2084 splitted_A_XC788023-Kjøttmeis-3-XC-wav-Helgøya-Elias-A_26_of_122.wav out of 2103 for bird Parus_major
# file already splitted, skipping
# splitting recording 2085 splitted_A_XC780700-Parus-major_male-song_16_02_23_Huergas-de-Babia_1_of_50.wav out of 2103 for bird Parus_major
# file already splitted, skipping
# splitting recording 2086 splitted_A_XC792271-P_71_of_543.wav out of 2103 for bird Parus_major
# file already splitted, skipping
# splitting recording 2087 splitted_A_XC792224-230407_15Cyanistes-cyaneus-11_7_of_21.wav out of 2103 for bird Parus_major
# file already splitted, skipping
# splitting recording 2088 splitted_A_XC788691-Par_3_of_18.wav out of 2103 for bird Parus_major
# file already splitted, skipping
# splitting recording 2089 splitted_A_XC791585-gt_20230224_162233_1_of_5.wav out of 2103 for bird Parus_major
# file already splitted, skipping
# splitting recording 2090 splitted_A_XC789902-2022_april_04_koolmees_1522hrs_Velada_GOKeijl_24_of_124.wav out of 2103 for bird Parus_major
# file already splitted, skipping
# splitting recording 2091 splitted_A_XC783340-Parus-mahor_2023_22_of_114.wav out of 2103 for bird Parus_major
# file already splitted, skipping
# splitting recording 2092 splitted_A_XC784686-Mésange-charbonnière-mâle-Chaussins-8-mars-2023-type-rapide_1_of_20.wav out of 2103 for bird Parus_major
# file already splitted, skipping
# splitting recording 2093 splitted_A_XC783554-MVI_5425_1_of_32.wav out of 2103 for bird Parus_major
# file already splitted, skipping
# splitting recording 2094 splitted_A_XC778753-230202_15Parus-major-18_48_of_165.wav out of 2103 for bird Parus_major
# file already splitted, skipping
# splitting recording 2095 splitted_A_XC792271-P_70_of_543.wav out of 2103 for bird Parus_major
# file already splitted, skipping
# splitting recording 2096 splitted_A_XC792271-P_171_of_543.wav out of 2103 for bird Parus_major
# file already splitted, skipping
# splitting recording 2097 splitted_A_XC787387-230321_06Parus-major-two-song-types-7_16_of_75.wav out of 2103 for bird Parus_major
# file already splitted, skipping
# splitting recording 2098 splitted_A_XC792271-P_61_of_543.wav out of 2103 for bird Parus_major
# file already splitted, skipping
# splitting recording 2099 splitted_A_XC780932-Parus-major_2023_5_of_83.wav out of 2103 for bird Parus_major
# file already splitted, skipping
# splitting recording 2100 splitted_A_XC787391-Parus-major_2023_11_of_36.wav out of 2103 for bird Parus_major
# file already splitted, skipping
# splitting recording 2101 splitted_A_XC789902-2022_april_04_koolmees_1522hrs_Velada_GOKeijl_5_of_124.wav out of 2103 for bird Parus_major
# file already splitted, skipping
# splitting recording 2102 splitted_A_XC784017-PARMAJ-s-VBO-230302_4997_44_of_151.wav out of 2103 for bird Parus_major
# file already splitted, skipping
# splitting recording 2103 splitted_A_XC787977-Kjøttmeis-Helgøya-Elias-A_19_of_109.wav out of 2103 for bird Parus_major
# file already splitted, skipping

# %% [markdown]
# ## Création des jeux de données

# %%
# create train, test and text pointers
recordings_folder = "recordings"
main_bird = "Parus major"

file_name = "testing_list.txt"

count = 0
with open(os.path.join(recordings_folder, file_name), "w", encoding="utf-8") as f:
    for bird_type in os.listdir(recordings_folder):
        bird_folder = os.path.join(recordings_folder, bird_type)
        if os.path.isdir(bird_folder):
            for recording in os.listdir(bird_folder):
                sound_filename = os.path.join(bird_folder, recording)
                if os.path.isfile(sound_filename) and "splitted_" in sound_filename:
                  if count < 1000:
                        if np.random.rand() > 0.3:
                            f.write(sound_filename + "\n")
                            count += 1
            count = 0
print("Done")
# Out:
# Done

# %% [markdown]
# ## Création des jeux de données

# %%
dataset_dir = Path('recordings')

CLASSES = ["Parus_major", "Turdus_merula", "Fringilla_coelebs"]

with (dataset_dir/ 'testing_list.txt').open(encoding='utf-8') as f:
    testing_list = f.read().splitlines()

x_train = []
y_train = []
x_test = []
y_test = []

for recording in dataset_dir.glob('**/*.wav'):
    if not recording.parent.name in CLASSES:
        continue
    if "splitted_" not in str(recording):
        continue
    label = CLASSES.index(recording.parent.name)

    with wave.open(str(recording)) as f :
        data = np.frombuffer(f.readframes(f.getnframes()), dtype=np.int16).copy()

    data = data.astype(np.float32)
    data.resize((16000, 1))

    if "splitted_" in str(recording):
        if str(recording) in testing_list:
            x_test.append(data)
            y_test.append(label)
        elif y_train.count(label) < 2400:
            x_train.append(data)
            y_train.append(label)

x_train = np.array(x_train)
y_train = to_categorical(np.array(y_train))
x_test = np.array(x_test)
y_test = to_categorical(np.array(y_test))

# %%
print(x_test.shape)
print(y_test.shape)
print(x_train.shape)
print(y_train.shape)
# Out:
# (3000, 16000, 1)
# (3000, 3)
# (7200, 16000, 1)
# (7200, 3)

# %%
unique_labels, label_counts = np.unique(y_train, return_counts=True)
for label, count in zip(unique_labels, label_counts):
    print(f"Label {label}: {count} occurrences")

# %% [markdown]
# ## Normalize data

# %%
x_mean = x_train.mean()
x_std = x_train.std()

x_train -= x_mean
x_test -= x_mean
x_train /= x_std
x_test /= x_std

# %% [markdown]
# ## Exporter les données

# %%
np.savetxt('x_test.csv', x_test.reshape(x_test.shape[0], -1), delimiter=',', fmt='%s')
np.savetxt('y_test.csv', y_test, delimiter=',', fmt='%s')

# %% [markdown]
# ## Build model M5

# %%
# Modifier

model = Sequential()
model.add(Input(shape=(16000, 1)))
model.add(MaxPool1D(pool_size=4, strides=3, padding='valid'))
model.add(Conv1D(filters=128, kernel_size=80, activation='relu'))
model.add(MaxPool1D(pool_size=4, strides=3, padding='valid'))
model.add(Conv1D(filters=64, kernel_size=3, activation='relu'))
model.add(MaxPool1D(pool_size=4, strides=3, padding='valid'))
model.add(Conv1D(filters=32, kernel_size=7, activation='relu'))
model.add(MaxPool1D(pool_size=4, strides=3, padding='valid'))
model.add(AvgPool1D())
# model.add(Conv1D(filters=128, kernel_size=80, strides=4, activation='relu'))
# model.add(MaxPool1D(pool_size=4, strides=1, padding='valid'))
# model.add(Conv1D(filters=128, kernel_size=3, activation='relu'))
# model.add(MaxPool1D(pool_size=4, strides=1, padding='valid'))
# model.add(Conv1D(filters=256, kernel_size=3, activation='relu'))
# model.add(MaxPool1D(pool_size=4, strides=1, padding='valid'))
# model.add(Conv1D(filters=512, kernel_size=3, activation='relu'))
# model.add(MaxPool1D(pool_size=4, strides=1, padding='valid'))
# model.add(AvgPool1D())
model.add(Flatten())
model.add(Dense(units=3))
model.add(Activation('softmax'))  # SoftMax activation needs to be separate from Dense to remove it later on
# EXPLORE Learning Rate
opt = tf.keras.optimizers.Adam(learning_rate=10e-4)
model.summary()
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  max_pooling1d_20 (MaxPoolin  (None, 5333, 1)          0
#  g1D)
#
#  conv1d_20 (Conv1D)          (None, 5254, 128)         10368
#
#  max_pooling1d_21 (MaxPoolin  (None, 1751, 128)        0
#  g1D)
#
#  conv1d_21 (Conv1D)          (None, 1749, 64)          24640
#
#  max_pooling1d_22 (MaxPoolin  (None, 582, 64)          0
#  g1D)
#
#  conv1d_22 (Conv1D)          (None, 576, 32)           14368
#
#  max_pooling1d_23 (MaxPoolin  (None, 191, 32)          0
#  g1D)
#
#  average_pooling1d_5 (Averag  (None, 95, 32)           0
#  ePooling1D)
#
#  flatten_5 (Flatten)         (None, 3040)              0
#
#  dense_5 (Dense)             (None, 3)                 9123
#
#  activation_5 (Activation)   (None, 3)                 0
#
# =================================================================
# Total params: 58,499
# Trainable params: 58,499
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Train model

# %%
model.fit(x_train, y_train, epochs=5, batch_size=100, validation_data=(x_test, y_test))
# Out:
# Epoch 1/5
# 72/72 [==============================] - 52s 81ms/step - loss: 1.0363 - categorical_accuracy: 0.4275 - val_loss: 0.9791 - val_categorical_accuracy: 0.5223
# Epoch 2/5
# 72/72 [==============================] - 5s 76ms/step - loss: 0.9671 - categorical_accuracy: 0.5271 - val_loss: 0.9308 - val_categorical_accuracy: 0.5413
# Epoch 3/5
# 72/72 [==============================] - 6s 77ms/step - loss: 0.9212 - categorical_accuracy: 0.5678 - val_loss: 0.8962 - val_categorical_accuracy: 0.5707
# Epoch 4/5
# 72/72 [==============================] - 6s 83ms/step - loss: 0.8773 - categorical_accuracy: 0.5844 - val_loss: 0.8766 - val_categorical_accuracy: 0.5900
# Epoch 5/5
# 72/72 [==============================] - 6s 77ms/step - loss: 0.8599 - categorical_accuracy: 0.5996 - val_loss: 0.8692 - val_categorical_accuracy: 0.5900

# %% [markdown]
# ## Evaluate model on test dataset

# %%
model.evaluate(x_test, y_test, verbose=2)
pred_test = model.predict(x_test)
print(tf.math.confusion_matrix(y_test.argmax(axis=1), pred_test.argmax(axis=1)))
# Out:
# 94/94 - 1s - loss: 0.8692 - categorical_accuracy: 0.5900 - 1s/epoch - 13ms/step
# 94/94 [==============================] - 1s 8ms/step
# tf.Tensor(
# [[455 151 394]
#  [105 622 273]
#  [130 177 693]], shape=(3, 3), dtype=int32)

# %% [markdown]
# ## Save trained model

# %%
model.save('lab_gsc.h5')

# %% [markdown]
# ## Remove SoftMax layer

# %%
model = tf.keras.Model(model.input, model.layers[-2].output, name=model.name)

# %% [markdown]
# ## Install MicroAI for C inference code generation (kerascnn2c module)

# %%
# !pip install https://bitbucket.org/edge-team-leat/microai_public/get/6adfbcb347d3.zip#subdirectory=third_party/kerascnn2c_fixed
import kerascnn2c
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting https://bitbucket.org/edge-team-leat/microai_public/get/6adfbcb347d3.zip#subdirectory=third_party/kerascnn2c_fixed
#   Downloading https://bitbucket.org/edge-team-leat/microai_public/get/6adfbcb347d3.zip (1.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 2.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from kerascnn2c==1.0.0) (1.22.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from kerascnn2c==1.0.0) (3.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->kerascnn2c==1.0.0) (2.1.2)
# Building wheels for collected packages: kerascnn2c
#   Building wheel for kerascnn2c (setup.py) ... done
#   Created wheel for kerascnn2c: filename=kerascnn2c-1.0.0-py3-none-any.whl size=21352 sha256=dc04e03924450f41b58b4325dff6a7343b528ddaa78861644d1112a6a5d3d87b
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ayyb125c/wheels/3c/1c/42/9f345b7c4830c9565167986fa8eeeb048f713a52913c845c66
# Successfully built kerascnn2c
# Installing collected packages: kerascnn2c
# Successfully installed kerascnn2c-1.0.0

# %% [markdown]
# ## Generate C code for the trained model with 16-bit fixed-point representation

# %%
res = kerascnn2c.Converter(output_path=Path('gsc_output_fixed'),
                           fixed_point=9, # Number of bits for the fractional part, Q7.9 format
                           number_type='int16_t', # Data type for weights/activations (16 bits quantization)
                           long_number_type='int32_t', # Data type for intermediate results
                           number_min=-(2**15), # Minimum value for 16-bit signed integers
                           number_max=(2**15)-1 # Maximum value for 16-bit signed integers
                          ).convert_model(copy.deepcopy(model))
with open('gsc_model_fixed.h', 'w') as f:
    f.write(res)
# Out:
# ———————————————————————————————————————————————————————————————————————————————————————————————————————
# Inputs                           | Layer                            | Outputs
# ———————————————————————————————————————————————————————————————————————————————————————————————————————
#                                  | input_6                          | max_pooling1d_20
# -------------------------------------------------------------------------------------------------------
# input_6                          | max_pooling1d_20                 | conv1d_20
# -------------------------------------------------------------------------------------------------------
# max_pooling1d_20                 | conv1d_20                        | max_pooling1d_21
# -------------------------------------------------------------------------------------------------------
# conv1d_20                        | max_pooling1d_21                 | conv1d_21
# -------------------------------------------------------------------------------------------------------
# max_pooling1d_21                 | conv1d_21                        | max_pooling1d_22
# -------------------------------------------------------------------------------------------------------
# conv1d_21                        | max_pooling1d_22                 | conv1d_22
# -------------------------------------------------------------------------------------------------------
# max_pooling1d_22                 | conv1d_22                        | max_pooling1d_23
# -------------------------------------------------------------------------------------------------------
# conv1d_22                        | max_pooling1d_23                 | average_pooling1d_5
# -------------------------------------------------------------------------------------------------------
# max_pooling1d_23                 | average_pooling1d_5              | flatten_5
# -------------------------------------------------------------------------------------------------------
# average_pooling1d_5              | flatten_5                        | dense_5
# -------------------------------------------------------------------------------------------------------
# flatten_5                        | dense_5                          |
# -------------------------------------------------------------------------------------------------------
#
# After optimization:
# ———————————————————————————————————————————————————————————————————————————————————————————————————————
# Inputs                           | Layer                            | Outputs
# ———————————————————————————————————————————————————————————————————————————————————————————————————————
#                                  | input_6                          | max_pooling1d_20
# -------------------------------------------------------------------------------------------------------
# input_6                          | max_pooling1d_20                 | conv1d_20
# -------------------------------------------------------------------------------------------------------
# max_pooling1d_20                 | conv1d_20                        | max_pooling1d_21
# -------------------------------------------------------------------------------------------------------
# conv1d_20                        | max_pooling1d_21                 | conv1d_21
# -------------------------------------------------------------------------------------------------------
# max_pooling1d_21                 | conv1d_21                        | max_pooling1d_22
# -------------------------------------------------------------------------------------------------------
# conv1d_21                        | max_pooling1d_22                 | conv1d_22
# -------------------------------------------------------------------------------------------------------
# max_pooling1d_22                 | conv1d_22                        | max_pooling1d_23
# -------------------------------------------------------------------------------------------------------
# conv1d_22                        | max_pooling1d_23                 | average_pooling1d_5
# -------------------------------------------------------------------------------------------------------
# max_pooling1d_23                 | average_pooling1d_5              | flatten_5
# -------------------------------------------------------------------------------------------------------
# average_pooling1d_5              | flatten_5                        | dense_5
# -------------------------------------------------------------------------------------------------------
# flatten_5                        | dense_5                          |
# -------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Compile the 16-bit fixed-point C code for x86 and evaluate on small dataset

# %%
# !g++ -Wall -Wextra -pedantic -Ofast -o gsc_fixed -Igsc_output_fixed/ gsc_output_fixed/model.c main.cpp
# !./gsc_fixed x_test_gsc_250.csv y_test_gsc_250.csv
# Out:
# gsc_output_fixed/model.c: In function â€˜void cnn(const number_t (*)[16000], number_t*)â€™:
# gsc_output_fixed/model.c:114:18: warning: left operand of comma operator has no effect [-Wunused-value]
#   114 |     activations2.max_pooling1d_68_output,
#       |     ~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~
# cc1plus: fatal error: main.cpp: No such file or directory
# compilation terminated.
# '.' n'est pas reconnu en tant que commande interne
# ou externe, un programme ex‚cutable ou un fichier de commandes.
