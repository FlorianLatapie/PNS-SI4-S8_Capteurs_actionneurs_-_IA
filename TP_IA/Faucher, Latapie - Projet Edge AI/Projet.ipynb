# %% [markdown]
# # Projet

# %% [markdown]
# ## Imports

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import copy
import wave
from pathlib import Path
import numpy as np
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Input, Conv1D, AvgPool1D, MaxPool1D, ZeroPadding1D, BatchNormalization, Flatten, Dense, Activation
from keras.utils.np_utils import to_categorical
import os
import requests
import librosa
import soundfile as sf

# %% [markdown]
# ## Récupération des données

# %%
def download_file(link, directory, filename):
    if os.path.exists(os.path.join(directory, filename)):
        print("File exists, skipping")
        return

    if not os.path.exists(directory):
        path = directory.split(os.sep)
        for i in range(1, len(path) + 1):
            sub_dir = os.path.join(*path[:i])
            if not os.path.exists(sub_dir):
                os.makedirs(sub_dir)

    with open(os.path.join(directory, filename), 'wb') as f:
        f.write(requests.get(link).content)
    f.close()


def get_bird_json(bird_name, recording_quality, number_of_recordings):
    api_base_link = "https://xeno-canto.org/api/2/recordings?query="
    quality_header = "q:"
    bird_name = "+".join(bird_name.split(" "))

    final_json = []

    for quality in recording_quality:
        print("Getting recordings data for", bird_name, "with quality", quality)
        api_link = api_base_link + bird_name + "+" + quality_header + quality
        json_recording = requests.get(api_link).json()["recordings"]
        final_json.extend(json_recording)

    final_json = [recording for recording in final_json if "song" in recording["type"]]
    return final_json[:number_of_recordings]


def download_from_bird_json_infos(recordings_folder, bird_json):
    len_bird_recordings = len(bird_json)
    for index, recording in enumerate(bird_json):
        print("Downloading file:", index + 1, "out of", len_bird_recordings, "(", recording["file-name"], ")")
        download_file(recording["file"], os.path.join(recordings_folder, recording["gen"] + "_" + recording["sp"]),
                      recording["q"] + "_" + recording["file-name"])

# %%
def split_audio_file(audio_file_path, output_folder, output_file_name, split_length=1):
    # if filename starts with splitted_ then skip
    if output_file_name.startswith("splitted_"):
        print("file already splitted, skipping")
        return
    if any("splitted_"+output_file_name in f for f in os.listdir(output_folder)):
        print("file already exists, skipping")
        return
    audio_signal, sample_rate = librosa.load(audio_file_path, sr=None)

    len_audio_signal = len(audio_signal)

    split_length_samples = split_length * sample_rate
    audio_signal = audio_signal[:len_audio_signal - len_audio_signal % split_length_samples]
    if len(audio_signal) > split_length:
        audio_signal = np.split(audio_signal, len(audio_signal) / split_length_samples)

    number_of_files = str(int(len_audio_signal / sample_rate))
    for index, y_split in enumerate(audio_signal):
        sf.write(
            os.path.join(output_folder,
                         "splitted_" + output_file_name + "_" + str(index + 1) + "_of_" + number_of_files + ".wav"),
            y_split, sample_rate)
    # os.remove(audio_file_path)

# %%
# parameters
main_bird = "Parus major"
main_bird_quality = ("A", "B", "C")
number_of_main_bird_recordings = 200

test_bird_1 = "Turdus merula"
test_bird_1_quality = ("A", "B", "C")
number_of_test_bird_1_recordings = 200

test_bird_2 = "Fringilla coelebs"
test_bird_2_quality = ("A", "B", "C")
number_of_test_bird_2_recordings = 200

recordings_folder = "recordings"

# dl data
main_bird_recordings_json = get_bird_json(main_bird, main_bird_quality, number_of_main_bird_recordings)
download_from_bird_json_infos(recordings_folder, main_bird_recordings_json)

test_bird_1_recordings_json = get_bird_json(test_bird_1, test_bird_1_quality, number_of_test_bird_1_recordings)
download_from_bird_json_infos(recordings_folder, test_bird_1_recordings_json)

test_bird_2_recordings_json = get_bird_json(test_bird_2, test_bird_2_quality, number_of_test_bird_2_recordings)
download_from_bird_json_infos(recordings_folder, test_bird_2_recordings_json)

# clean data

print("splitting audio into multiple recordings")
for bird_type in os.listdir(recordings_folder):
    bird_folder = os.path.join(recordings_folder, bird_type)
    print("looking into folder:", bird_folder)
    if os.path.isdir(bird_folder):
        number_of_recordings = len(os.listdir(bird_folder))
        for index, recording in enumerate(os.listdir(bird_folder)):
            print("splitting recording", str(index+1), recording, "out of", number_of_recordings, "for bird", bird_type)
            recording_path = os.path.join(bird_folder, recording)
            split_audio_file(recording_path, bird_folder, recording.split(".")[0], 3)
# Out:
# Getting recordings data for Parus+major with quality A
# Getting recordings data for Parus+major with quality B
# Getting recordings data for Parus+major with quality C
# Downloading file: 1 out of 200 ( XC795227-d)charbo.mp3 )
# Downloading file: 2 out of 200 ( XC795108-230404_11Parus-major-song-10.30-Camiño-galegas,-Biobra,-Rubiá.mp3 )
# Downloading file: 3 out of 200 ( XC794967-230403_41-Parus-major-14.30-Covas,-Rubiá.mp3 )
# Downloading file: 4 out of 200 ( XC794645-MVI_5842.mp3 )
# Downloading file: 5 out of 200 ( XC793834-pmajor_230415_aluvium.wav )
# Downloading file: 6 out of 200 ( XC793240-230413_1596-1739-Kohlmeise.-CZ,-Becov-nad-Teplou.-Stephan-Risch.wav )
# Downloading file: 7 out of 200 ( XC793160-Kohlmeise--Würmseeplatz--München.mp3 )
# Downloading file: 8 out of 200 ( XC793158-Kohlmeise--Ambacher-Straße--München.mp3 )
# Downloading file: 9 out of 200 ( XC792834-Tit,-Great-(Nové-Mlyny)-19.4.22-SF.mp3 )
# Downloading file: 10 out of 200 ( XC792650-20230411_171921-cinciallegra.mp3 )
# Downloading file: 11 out of 200 ( XC792271-P.-major--230406_012б-(3-50),AABB-song.mp3 )
# Downloading file: 12 out of 200 ( XC792224-230407_15Cyanistes-cyaneus-11.00-Brandomil,-Zas.mp3 )
# Downloading file: 13 out of 200 ( XC791965-pmajor_230409_cyklomost.wav )
# Downloading file: 14 out of 200 ( XC791907-2023-04-08-GT-clip.wav )
# Downloading file: 15 out of 200 ( XC791861-greattit.wav )
# Downloading file: 16 out of 200 ( XC791687-greattit.wav )
# Downloading file: 17 out of 200 ( XC791585-gt_20230224_162233.mp3 )
# Downloading file: 18 out of 200 ( XC791584-gt_20230224_162157.mp3 )
# Downloading file: 19 out of 200 ( XC791582-gt_20230224_162057.mp3 )
# Downloading file: 20 out of 200 ( XC791290-gt1_20230223_155641.mp3 )
# Downloading file: 21 out of 200 ( XC791289-gt_20230223_155641.mp3 )
# Downloading file: 22 out of 200 ( XC791150-MVI_5364.mp3 )
# Downloading file: 23 out of 200 ( XC790607-Kjøttmeis-5-XC-Helgøya-Elias-A.-Ryberg20230401141928_025.wav )
# Downloading file: 24 out of 200 ( XC790541-Great-Tit大山雀-call-ABCA-2301270737-松江叶榭SHADOW_2873S12.mp3 )
# Downloading file: 25 out of 200 ( XC790539-Great-Tit大山雀-call-2302260859-松江叶榭SHADOW_2960S12.mp3 )
# Downloading file: 55 out of 200 ( XC785791-20230228_Kohlmeise_Lockenhaus.mp3 )
# Downloading file: 56 out of 200 ( XC785534-Kjøttmeis-XC-7-Helgøya-Elias-A.-Ryberg20230311124711_003.mp3 )
# Downloading file: 57 out of 200 ( XC785494-PJ-jak-PA_Police_230312_01.mp3 )
# Downloading file: 58 out of 200 ( XC785412-Kjøttmeis-XC-6-Helgøya-Elias-A.-Ryberg20230311124406_002.mp3 )
# Downloading file: 59 out of 200 ( XC785394-Kjøttmeis-XC-4-Helgøya-Elias-A.-Ryberg20230310152833_020.mp3 )
# Downloading file: 60 out of 200 ( XC785379-Kjøttmeis-3-Helgøya-Elias-A.-Ryberg20230310150416_016.wav )
# Downloading file: 61 out of 200 ( XC785378-Kjøttmeis-XC-3-Helgøya-Elias-A.-Ryberg20230310150416_016.mp3 )
# Downloading file: 62 out of 200 ( XC785370-KOHLMEISE,-Ruf-und-Gesang---HhWald--8_52-VOC_230221-3575.wav )
# Downloading file: 63 out of 200 ( XC785342-koolmees_drongengoed_2A.mp3 )
# Downloading file: 64 out of 200 ( XC785341-koolmees_drongengoed.mp3 )
# Downloading file: 65 out of 200 ( XC785313-230220_29Parus-major-call-male-12.30-Con-do-forno,-Arousa.mp3 )
# Downloading file: 66 out of 200 ( XC784686-Mésange-charbonnière-mâle-Chaussins-8-mars-2023-type-rapide.mp3 )
# Downloading file: 67 out of 200 ( XC784685-Mésange-charbonnière-mâle-Chaussins-8-mars-2023-type-lent.mp3 )
# Downloading file: 68 out of 200 ( XC784401-06-03-2023-(mésange-charbonnière,-chant,-fagne-de-Brackvenn).wav )
# Downloading file: 69 out of 200 ( XC784296-Kjøttmeis-Helgøya-Elias-A.-Ryberg-06.03-2023-14.38.48---klipp-1.mp3 )
# Downloading file: 70 out of 200 ( XC784259-STE-000-M.mp3 )
# Downloading file: 71 out of 200 ( XC784017-PARMAJ-s-VBO-230302_4997.mp3 )
# Downloading file: 72 out of 200 ( XC784015-PARMAJ-s-VBO-230227_4994.mp3 )
# Downloading file: 73 out of 200 ( XC783621-Talgoxe_39.mp3 )
# Downloading file: 74 out of 200 ( XC783556-MVI_5436.mp3 )
# Downloading file: 75 out of 200 ( XC783554-MVI_5425.mp3 )
# Downloading file: 76 out of 200 ( XC783546-MVI_5424.mp3 )
# Downloading file: 77 out of 200 ( XC783420-Parus-major_2023.01.31_10.07_011.mp3 )
# Downloading file: 78 out of 200 ( XC783340-Parus-mahor_2023.01.19_09.42-1_012.mp3 )
# Downloading file: 79 out of 200 ( XC783325-Parus-major_2023.01.18_10.10.mp3 )
# Downloading file: 80 out of 200 ( XC783299-Parus-Major_2023.01.19_09.50_02.mp3 )
# Downloading file: 81 out of 200 ( XC783165-Parus-major_2023.02.04_10.11_02.mp3 )
# Downloading file: 82 out of 200 ( XC782693-d)Charbo%22extra%22.mp3 )
# Downloading file: 83 out of 200 ( XC782225-STE-000.charbonniere.mp3 )
# Downloading file: 84 out of 200 ( XC782124-PJ_Szczecin_220415_02.mp3 )
# Downloading file: 85 out of 200 ( XC782123-PJ_Szczecin_220415_03.mp3 )
# Downloading file: 86 out of 200 ( XC782012-pmajor_230222_mlaka.wav )
# Downloading file: 118 out of 200 ( XC776448-+-2023-01-21-Arezzo-(presso-Via-Curtatone).mp3 )
# Downloading file: 119 out of 200 ( XC775537-d)Mechar(extravaganza).mp3 )
# Downloading file: 120 out of 200 ( XC775044-0111_130741-s-puurs.wav )
# Downloading file: 121 out of 200 ( XC774718-Parus-major_song_10_01_23_Laguna-del-Castro.wav )
# Downloading file: 122 out of 200 ( XC774708-Great-Tit.mp3 )
# Downloading file: 123 out of 200 ( XC773820-Kohlmeise_Gesang_Saumgasse_Graz_080123.mp3 )
# Downloading file: 124 out of 200 ( XC773452-KOHLMEISEN-,-Wechselgesang--23.09.2022--Schwifting--10_53--VOC_220923-3293.wav )
# Downloading file: 125 out of 200 ( XC773390-pmajor_230106_spev_plaz.wav )
# Downloading file: 126 out of 200 ( XC772616-Parus-major_2022.12.23_11.40_01.mp3 )
# Downloading file: 127 out of 200 ( XC770769-Koolmees-zang---Bodegraven---2021-04-22---0556-copy.mp3 )
# Downloading file: 128 out of 200 ( XC770768-Koolmees-zang---Bodegraven---2020-05-03---0550-copy.mp3 )
# Downloading file: 129 out of 200 ( XC770764-Koolmees-roep-en-zang---Bodegraven---2019-05-02---0525-copy.mp3 )
# Downloading file: 130 out of 200 ( XC770763-Koolmees-roep-en-zang---Bodegraven---2019-05-01---0544-copy.mp3 )
# Downloading file: 131 out of 200 ( XC770608-Mésange-charbonnière,-chant,-maison,-26-04-22.mp3 )
# Downloading file: 132 out of 200 ( XC770606-Mésange-charbonnière,-chant,-maison,-26-04-22-(3).mp3 )
# Downloading file: 133 out of 200 ( XC769719-Koolmees-zang---Reeuwijk---2021-03-31---1902-copy.mp3 )
# Downloading file: 134 out of 200 ( XC757053-Great-Tit_20200418_121003_prepared.mp3 )
# Downloading file: 135 out of 200 ( XC757024-Great-Tit_20200418_084658_prepared.mp3 )
# Downloading file: 136 out of 200 ( XC756166-221014_12Parus-major-song-16.30-Lagoa-de-Vixán.mp3 )
# Downloading file: 137 out of 200 ( XC750629-ZOOM0012X  Büyük Baştankara.mp3 )
# Downloading file: 138 out of 200 ( XC750627-ZOOM0011X Büyük Baştankara.mp3 )
# Downloading file: 139 out of 200 ( XC750626-ZOOM0004X  Büyük Baştankara.mp3 )
# Downloading file: 140 out of 200 ( XC746996-Kjøttmeis XC  Helgøya Z Elias A. Ryberg20220323141639_041.mp3 )
# Downloading file: 141 out of 200 ( XC745018-Cinciallegra ad e juv ariamacina.mp3 )
# Downloading file: 142 out of 200 ( XC744164-220619_2718-10.30_Par.major.mp3 )
# Downloading file: 143 out of 200 ( XC741814-60.mp3 )
# Downloading file: 144 out of 200 ( XC741672-Parus major_2022.08.05_09.06_01 2.mp3 )
# Downloading file: 145 out of 200 ( XC741377-210204_2781 Kohlmeise. D, LEV, Bürgerbusch N. Stephan Risch.mp3 )
# Downloading file: 146 out of 200 ( XC737812-1122 Koolmeeszang coolhem.mp3 )
# Downloading file: 147 out of 200 ( XC735437-T1Kohlmeise.mp3 )
# Downloading file: 148 out of 200 ( XC733243-220621_4965 4966 Koolmees.mp3 )
# Downloading file: 149 out of 200 ( XC732508-Mesangecharbonniere_15102021_carollesvauban_9h00 cri et chant posé.mp3 )
# Downloading file: 150 out of 200 ( XC732026-Tit_Great3_SDMKH-368_EdensGardenForestEdge_Dawn_6thJune22.mp3 )
# Downloading file: 151 out of 200 ( XC732025-Tit_Great2_SDMKH-368_EdensGardenForestEdge_Dawn_6thJune22.mp3 )
# Downloading file: 152 out of 200 ( XC731709-PARMAJ290522-T001_SONG (2).mp3 )
# Downloading file: 153 out of 200 ( XC730822-Mesangecharbonniere_130522_chauseypont_9h.mp3 )
# Downloading file: 154 out of 200 ( XC729993-kohl0452.mp3 )
# Downloading file: 155 out of 200 ( XC728634-Parus major_2022.05.31_10.39_01.mp3 )
# Downloading file: 156 out of 200 ( XC727901-Parus major_2022.05.27_18.44_01.MP3 )
# Downloading file: 157 out of 200 ( XC726960-Kohlmeise.mp3 )
# Downloading file: 158 out of 200 ( XC726378-220512_07Parus major 13.00 Laíño 1.mp3 )
# Downloading file: 159 out of 200 ( XC726196-Kjøttmeis XC Helgøya Elias A. Ryberg20220522153022_067.mp3 )
# Downloading file: 160 out of 200 ( XC725768-220513_04Parus major 16.00 Mourozos-Tamaguelos, Oimbra.mp3 )
# Downloading file: 161 out of 200 ( XC725753-220513_61Parus major 21.30 Castelo de Monterrei, Verín.mp3 )
# Downloading file: 162 out of 200 ( XC725588-220513-0627 P. major - Vulturilor.mp3 )
# Downloading file: 163 out of 200 ( XC724867-220516_9773 Koolmees.mp3 )
# Downloading file: 164 out of 200 ( XC724642-parus_major_gugny_podlaskie_2022.05.15_0602.mp3 )
# Downloading file: 165 out of 200 ( XC724372-R00260.mp3 )
# Downloading file: 166 out of 200 ( XC724068-PARMAJ_220513_1984_Marcevol66.mp3 )
# Downloading file: 167 out of 200 ( XC723457-PARMAJ SUURERANNA 220501_4169.mp3 )
# Downloading file: 168 out of 200 ( XC723455-PARMAJ SUURERANNA 220430_4166.mp3 )
# Downloading file: 169 out of 200 ( XC722770-220429_01_Great Tit_Urdenbacher Altrhein und Baumberger Aue, DUS, Germany_28 April 2022.mp3 )
# Downloading file: 170 out of 200 ( XC722469-Possible Coal Tit 220507_session.mp3 )
# Downloading file: 171 out of 200 ( XC722044-Mésange charbonniere song le plessis may 4 851_3547.mp3 )
# Downloading file: 172 out of 200 ( XC721036-Kjøttmeis XC 1 Balberg Elias A. Ryberg20220501153509_045.mp3 )
# Downloading file: 173 out of 200 ( XC720773-07 Great Tit.mp3 )
# Downloading file: 174 out of 200 ( XC720292-PARMAJ VBO 220429_4163.mp3 )
# Downloading file: 175 out of 200 ( XC720193-Mesange charbonniere song la chapelle sur erdre apr 27 1631_3451.mp3 )
# Downloading file: 176 out of 200 ( XC720088-220413-0627 P. major Arató u..mp3 )
# Downloading file: 177 out of 200 ( XC719660-PARMAJ VIHTRA R3 220416_4050.mp3 )
# Downloading file: 178 out of 200 ( XC719602-PARMAJ Laeva pt 17 220413_4022.mp3 )
# Downloading file: 179 out of 200 ( XC718673-220306_001_Tr1_2.mp3 )
# Downloading file: 180 out of 200 ( XC718410-Kjøttmeis XC Helgøya Elias A. Ryberg20220420113926_084.mp3 )
# Downloading file: 181 out of 200 ( XC718274-Mesange charbonniere male calls apr 23 1557_3303.mp3 )
# Downloading file: 182 out of 200 ( XC717265-220417-094715chapimreal.mp3 )
# Downloading file: 183 out of 200 ( XC717165-220421x2113.mp3 )
# Downloading file: 184 out of 200 ( XC717149-greattit.mp3 )
# Downloading file: 185 out of 200 ( XC717009-2022.04.18_19.06_01.mp3 )
# Downloading file: 186 out of 200 ( XC716952-Parus major-2022.04.18_11_11.MP3 )
# Downloading file: 187 out of 200 ( XC716880-2022.04.19_11.18_01.MP3 )
# Downloading file: 188 out of 200 ( XC716749-Kjøttmeis XC 4 Helgøya Elias A. Ryberg20220418092316_023.mp3 )
# Downloading file: 189 out of 200 ( XC716606-charbo.mp3 )
# Downloading file: 190 out of 200 ( XC716420-Cinciallegra song_0418_1530.mp3 )
# Downloading file: 191 out of 200 ( XC716392-Kjøttmeis XC 5 Helgøya Elias A. Ryberg20220418094643_030.mp3 )
# Downloading file: 192 out of 200 ( XC716368-Kjøttmeis XC 4 Helgøya Elias A. Ryberg20220418102547_036.mp3 )
# Downloading file: 193 out of 200 ( XC716335-Kjøttmeis XC  3 Helgøya Elias A. Ryberg20220418122452_049.mp3 )
# Downloading file: 194 out of 200 ( XC716325-Kjøttmeis XC 2 Helgøya Elias A. Ryberg20220418114739_043.mp3 )
# Downloading file: 195 out of 200 ( XC716153-220417_parmaj_song_1.mp3 )
# Downloading file: 196 out of 200 ( XC715999-Kjøttmeis XC 2 Helgøya Elias A. Ryberg20220416131336_041.mp3 )
# Downloading file: 197 out of 200 ( XC715983-220416_6683 Koolmees.mp3 )
# Downloading file: 198 out of 200 ( XC715846-Mésange charbonnière chant La Motte 15 04 2022.mp3 )
# Downloading file: 199 out of 200 ( XC715487-220412_parmaj_song_1.mp3 )
# Downloading file: 200 out of 200 ( XC714966-Kjøttmeis  XC 2 Helgøya Elias A. Ryberg20220412134905_047.mp3 )
# Getting recordings data for Turdus+merula with quality A
# Getting recordings data for Turdus+merula with quality B
# Getting recordings data for Turdus+merula with quality C
# Downloading file: 1 out of 200 ( XC794897-Turdus-merula_song-male_200423_Escober-de-Tabara.wav )
# Downloading file: 2 out of 200 ( XC794896-Common-Blackbird-1.mp3 )
# Downloading file: 3 out of 200 ( XC794865-blackbird.wav )
# Downloading file: 4 out of 200 ( XC794533-blackbird.wav )
# Downloading file: 5 out of 200 ( XC794140-merelzang.wav )
# Downloading file: 6 out of 200 ( XC794025-TurmerTop2_Jardim-Botânico-de-Pedro-Miguel.wav )
# Downloading file: 7 out of 200 ( XC794024-TurmerTop1_Jardim-Botânico-de-Pedro-Miguel.wav )
# Downloading file: 8 out of 200 ( XC793995-Turdus-merula_2023.04.14_19.54_01.mp3 )
# Downloading file: 9 out of 200 ( XC793975-20230316_150905-merlo-Bertignano-.mp3 )
# Downloading file: 10 out of 200 ( XC793974-20230417_133913-merlo-palazzi-masseria.mp3 )
# Downloading file: 11 out of 200 ( XC793567-turmer_20230415_rodersdorf_ZOOM0232_Tr1.mp3 )
# Downloading file: 12 out of 200 ( XC793205-2023-04-13-13_17.wav )
# Downloading file: 13 out of 200 ( XC792991-TURMER-2023-04-11-07-49-SIPOONKORPI-s-A.wav )
# Downloading file: 14 out of 200 ( XC792833-Turdus-merula_song-male_08_04_23_Villablino.wav )
# Downloading file: 15 out of 200 ( XC792322-Turdus-merula_SONG_Etang-de-LIndre_230408_0722.wav )
# Downloading file: 16 out of 200 ( XC792107-Turdus-merula_song_10_04_23_Parque-Villablino.wav )
# Downloading file: 17 out of 200 ( XC792089-Koltrast_35.mp3 )
# Downloading file: 18 out of 200 ( XC791650-AUD-20230407-WA0023.mp3 )
# Downloading file: 19 out of 200 ( XC791638-EuB_20230302_141445.mp3 )
# Downloading file: 20 out of 200 ( XC791632-EuB_20230221_174338.mp3 )
# Downloading file: 21 out of 200 ( XC791347-220604_018_Tr1.mp3 )
# Downloading file: 22 out of 200 ( XC791288-220531_016_Tr1.mp3 )
# Downloading file: 23 out of 200 ( XC791270-220530_010_Tr1.mp3 )
# Downloading file: 24 out of 200 ( XC790089-220515_012_Tr1.mp3 )
# Downloading file: 25 out of 200 ( XC789842-220501_001_Tr1.mp3 )
# Downloading file: 26 out of 200 ( XC789663-2022_april_02_merel_1811hrs_TorrejonElRubio_GOKeijl.mp3 )
# Downloading file: 27 out of 200 ( XC789465-amsel0622.mp3 )
# Downloading file: 28 out of 200 ( XC789456-Turdus-merula-cabrerae-(Tenerfe)---Monte-de-Las-Vueltas-(Anaga).mp3 )
# Downloading file: 29 out of 200 ( XC789328-Turdus-merula_2023.03.28_19.48_01.mp3 )
# Downloading file: 30 out of 200 ( XC788931-merel_ochtend.mp3 )
# Downloading file: 31 out of 200 ( XC788912-2023.03.28_11.36_01.mp3 )
# Downloading file: 32 out of 200 ( XC788737-turdus-merula_2023.03.24_16.30_01.mp3 )
# Downloading file: 33 out of 200 ( XC788734-Turdus-merula_2023.03.24_15.35_01.mp3 )
# Downloading file: 34 out of 200 ( XC788555-Clamart-FR92-2023_03_24_04_42_26.wav )
# Downloading file: 35 out of 200 ( XC788381-Amsel_Aichtal_20230322_0527_Gesang.wav )
# Downloading file: 36 out of 200 ( XC788379-Amsel_Aichtal_20230320_0528_Gesang.wav )
# Downloading file: 37 out of 200 ( XC788378-Amsel_Aichtal_20230319_1853_Gesang.wav )
# Downloading file: 38 out of 200 ( XC787982-Solsort-(Turdus-merula)-Gludsted-Plantage_20230317-1817-sang.mp3 )
# Downloading file: 39 out of 200 ( XC787811-AMSEL,-dawn--23.03.2023--Kirchstr.--5_20--VOC_230323-3763.mp3 )
# Downloading file: 40 out of 200 ( XC787580-Turdus_merula2-(mp3cut.net).mp3 )
# Downloading file: 41 out of 200 ( XC787454-B.6348D117.wav )
# Downloading file: 42 out of 200 ( XC787385-230321_04Turdus-merula-7.00-parque-lavadeiro,-Bertamiráns.mp3 )
# Downloading file: 43 out of 200 ( XC787340-Chant-d’oiseau-Champ-merle-matin.mp3 )
# Downloading file: 44 out of 200 ( XC787146-S_TURMER_230319-0619_1.mp3 )
# Downloading file: 45 out of 200 ( XC787144-S_TURMER_230319-0617_1.mp3 )
# Downloading file: 46 out of 200 ( XC786571-blackbird.wav )
# Downloading file: 47 out of 200 ( XC786387-DM671522-(mp3cut.net).mp3 )
# Downloading file: 48 out of 200 ( XC786386-DM671520__V.mp3 )
# Downloading file: 49 out of 200 ( XC785832-turdus-merula_2023.03.10_17.30_03.mp3 )
# Downloading file: 50 out of 200 ( XC785469-AMSEL,-singing-in-dusk--HhWald--18_38---VOC_230311-3684.wav )
# Downloading file: 51 out of 200 ( XC784706-230306_11Turdus-merula-17.30-Xinzo,-Brión.mp3 )
# Downloading file: 52 out of 200 ( XC784705-230306_10Turdus-merula-17.30-Xinzo-Brión.mp3 )
# Downloading file: 53 out of 200 ( XC784704-230306_09-Turdus-merula-relaxed-song--17.30-Xinzo,-Brión.mp3 )
# Downloading file: 54 out of 200 ( XC783414-Turdus-merula2023.01.28_07.34_011.mp3 )
# Downloading file: 55 out of 200 ( XC783413-Turdus-merula_2023.01.28_07.31_01.mp3 )
# Downloading file: 56 out of 200 ( XC783412-Turdus-merula_2023.01.28_07.30_01.mp3 )
# Downloading file: 57 out of 200 ( XC783138-230228_2310-Merel.mp3 )
# Downloading file: 58 out of 200 ( XC783137-230228_2293-Merel.mp3 )
# Downloading file: 59 out of 200 ( XC782475-20230215_174058-merlo.mp3 )
# Downloading file: 60 out of 200 ( XC780272-blackbirdsongtacfeb23.wav )
# Downloading file: 61 out of 200 ( XC780271-blackbirdsongtacfeb232.wav )
# Downloading file: 62 out of 200 ( XC779952-230212_1497-tm-1511-Merel.mp3 )
# Downloading file: 63 out of 200 ( XC776596-amsel_bipsiboy_garten_kristein_22012023morgen1.mp3 )
# Downloading file: 64 out of 200 ( XC773067-blackbird-11_26_14.mp3 )
# Downloading file: 65 out of 200 ( XC772543-55.-Pastorsumsel-7.-April.mp3 )
# Downloading file: 66 out of 200 ( XC772540-45.-Feulgenamsel-2.-April.mp3 )
# Downloading file: 67 out of 200 ( XC770779-Merel-zang---Bodegraven---2022-05-15---0923-copy.mp3 )
# Downloading file: 68 out of 200 ( XC770778-Merel-zang---Bodegraven---2022-05-15---0906-copy.mp3 )
# Downloading file: 69 out of 200 ( XC770777-Merel-zang---Bodegraven---2022-05-15---0832-copy.mp3 )
# Downloading file: 70 out of 200 ( XC770776-Merel-zang---Bodegraven---2022-05-04---0719-copy.mp3 )
# Downloading file: 71 out of 200 ( XC770775-Merel-zang---Bodegraven---2022-04-03---0915-copy.mp3 )
# Downloading file: 72 out of 200 ( XC770774-Merel-zang---Bodegraven---2022-04-03---0824-copy.mp3 )
# Downloading file: 73 out of 200 ( XC770773-Merel-zang---Bodegraven---2022-03-30---0633-copy.mp3 )
# Downloading file: 74 out of 200 ( XC770772-Merel-zang---Bodegraven---2022-03-28---0736-copy.mp3 )
# Downloading file: 75 out of 200 ( XC769885-54-Mondamsel-7.-April.mp3 )
# Downloading file: 76 out of 200 ( XC769884-53.-Schwarzspechtamsel-7.-April.mp3 )
# Downloading file: 77 out of 200 ( XC769882-52.-Spindelpastorsamsel-7.-April.mp3 )
# Downloading file: 78 out of 200 ( XC769861-51.-Pastorsamsel-7.-April.mp3 )
# Downloading file: 79 out of 200 ( XC769859-50.-Weckeramsel-7.-April.mp3 )
# Downloading file: 80 out of 200 ( XC769856-49.-Mondumsel-7.-April.mp3 )
# Downloading file: 81 out of 200 ( XC769855-48.-Gimpelamsel-6.-April.mp3 )
# Downloading file: 82 out of 200 ( XC769854-47.-Telefonamsel-6.-April.mp3 )
# Downloading file: 83 out of 200 ( XC769851-45.-Feulgenamsel-2.-April.mp3 )
# Downloading file: 84 out of 200 ( XC769843-44.-Tuchmacheramsel-2.-April.mp3 )
# Downloading file: 85 out of 200 ( XC769841-43.-Sirenenamsel-2.-April.mp3 )
# Downloading file: 86 out of 200 ( XC769212-Merel-zang---Hollum---2021-04-15---2107-copy.mp3 )
# Downloading file: 87 out of 200 ( XC769176-Merel-zang---Hoenderloo---2022-05-10---1808-copy.mp3 )
# Downloading file: 88 out of 200 ( XC767007-Tenerife-Blackbird-051222-1830.mp3 )
# Downloading file: 89 out of 200 ( XC764870-DM671083-(mp3cut.net).mp3 )
# Downloading file: 90 out of 200 ( XC764740-221203_003.mp3 )
# Downloading file: 91 out of 200 ( XC764739-221203_002.mp3 )
# Downloading file: 92 out of 200 ( XC764738-221203_001.mp3 )
# Downloading file: 93 out of 200 ( XC761300-Blackbird.mp3 )
# Downloading file: 94 out of 200 ( XC759976-Merel-20220522-1720-1a.mp3 )
# Downloading file: 95 out of 200 ( XC759431-220327-Amsel-Gesang-FH-0610-MP3.mp3 )
# Downloading file: 96 out of 200 ( XC758225-Merel,-winter-zang,-IGS,-101022,-0552-uur.mp3 )
# Downloading file: 97 out of 200 ( XC751020-TURMER-2022-06-05-08-27-VRKL-ab,c,s-A.mp3 )
# Downloading file: 98 out of 200 ( XC750372-xc-wa013316-000012.mp3 )
# Downloading file: 99 out of 200 ( XC749155-220311 MP-1055 Claude merle.mp3 )
# Downloading file: 100 out of 200 ( XC749119-220316 Amsel Gesang FH 0642 MP3 QA.mp3 )
# Downloading file: 101 out of 200 ( XC749118-220316 Amsel Gesang FH 0634 MP3 QA.mp3 )
# Downloading file: 102 out of 200 ( XC749114-220316 Amsel Gesang FH 0629 MP3 QA.mp3 )
# Downloading file: 103 out of 200 ( XC749111-220316 Amsel Gesang FH 0557 MP3 QA.mp3 )
# Downloading file: 104 out of 200 ( XC744880-220726_Eurasian Blackbird_song_Senatta area_TC_OC.mp3 )
# Downloading file: 105 out of 200 ( XC744147-Common Blackbird_hunting lodge2_DLY.mp3 )
# Downloading file: 106 out of 200 ( XC742937-220503_2521-7.45_T.merula.mp3 )
# Downloading file: 107 out of 200 ( XC742900-220503_2505-6.40_T.merula.mp3 )
# Downloading file: 108 out of 200 ( XC741788-220311 MP-1053 fil rue pair merle.mp3 )
# Downloading file: 109 out of 200 ( XC738419-DM-_20220424_190000_Tur.merula_Wieprz.mp3 )
# Downloading file: 110 out of 200 ( XC737544-koltrast bra sång 220712_hemma.mp3 )
# Downloading file: 111 out of 200 ( XC735706-220320 Amsel Gesang FH 1642 1900 MP3 Ruf.mp3 )
# Downloading file: 112 out of 200 ( XC735705-220320 Amsel Gesang FH 1642 1855 MP3.mp3 )
# Downloading file: 113 out of 200 ( XC735704-220320 Amsel Gesang FH 1642 1834 MP3.mp3 )
# Downloading file: 114 out of 200 ( XC735702-220320 Amsel Gesang FH 1642 1717 MP3.mp3 )
# Downloading file: 115 out of 200 ( XC735700-220320 Amsel Gesang FH 1642 1644 MP3.mp3 )
# Downloading file: 116 out of 200 ( XC735409-220320 Amsel Gesang FH 1336 1625 MP3 Ultra-chrystallised Song.mp3 )
# Downloading file: 117 out of 200 ( XC735407-220320 Amsel Gesang FH 1336 1557 MP3.mp3 )
# Downloading file: 118 out of 200 ( XC735406-220320 Amsel Gesang FH 1336 1546 MP3 Subsong.mp3 )
# Downloading file: 119 out of 200 ( XC735404-220320 Amsel Gesang FH 1336 1515 MP3.mp3 )
# Downloading file: 120 out of 200 ( XC735403-220320 Amsel Gesang FH 1336 1414 MP3.mp3 )
# Downloading file: 121 out of 200 ( XC735401-220320 Amsel Gesang FH 1336 1402 MP3.mp3 )
# Downloading file: 122 out of 200 ( XC735399-220320 Amsel Gesang FH 1336 1401 MP3.mp3 )
# Downloading file: 123 out of 200 ( XC735397-220320 Amsel Gesang FH 1336 1350 Stieglitz MP3.mp3 )
# Downloading file: 124 out of 200 ( XC735394-220320 Amsel Gesang FH 1029 1202 MP3.mp3 )
# Downloading file: 125 out of 200 ( XC735393-220320 Amsel Gesang FH 0723 0911 MP3.mp3 )
# Downloading file: 126 out of 200 ( XC735392-220320 Amsel Gesang FH 0723 0904 MP3.mp3 )
# Downloading file: 127 out of 200 ( XC735391-220320 Amsel Gesang FH 0723 0858 MP3.mp3 )
# Downloading file: 128 out of 200 ( XC735390-220320 Amsel Gesang FH 0723 0850 MP3.mp3 )
# Downloading file: 129 out of 200 ( XC735389-220320 Amsel Gesang FH 0723 0810 MP3.mp3 )
# Downloading file: 130 out of 200 ( XC735388-220320 Amsel Gesang FH 0723 0806 MP3.mp3 )
# Downloading file: 131 out of 200 ( XC735387-220320 Amsel Gesang FH 0723 0802 MP3.mp3 )
# Downloading file: 132 out of 200 ( XC735386-220320 Amsel Gesang FH 0723 0752 MP3.mp3 )
# Downloading file: 133 out of 200 ( XC735385-220320 Amsel Gesang FH 0723 0745 MP3.mp3 )
# Downloading file: 134 out of 200 ( XC735384-220320 Amsel Gesang FH 0723 0742 MP3.mp3 )
# Downloading file: 135 out of 200 ( XC735383-220320 Amsel Gesang FH 0723 0740 MP3.mp3 )
# Downloading file: 136 out of 200 ( XC735382-220320 Amsel Gesang FH 0417 0722 MP3.mp3 )
# Downloading file: 137 out of 200 ( XC735381-220320 Amsel Gesang FH 0417 0718 MP3.mp3 )
# Downloading file: 138 out of 200 ( XC735380-220320 Amsel Gesang FH 0417 0708 MP3.mp3 )
# Downloading file: 139 out of 200 ( XC735379-220320 Amsel Gesang FH 0417 0656 MP3 Ultra-chrystallised Song Rufe.mp3 )
# Downloading file: 140 out of 200 ( XC735377-220320 Amsel Gesang FH 0417 0645 MP3 Rufe.mp3 )
# Downloading file: 141 out of 200 ( XC735375-220320 Amsel Gesang FH 0417 0630 MP3 Ruf.mp3 )
# Downloading file: 142 out of 200 ( XC735374-220320 Amsel Gesang FH 0417 0622 MP3.mp3 )
# Downloading file: 143 out of 200 ( XC735373-220320 Amsel Gesang FH 0417 0620 MP3.mp3 )
# Downloading file: 144 out of 200 ( XC735372-220320 Amsel Gesang FH 0417 0559 MP3.mp3 )
# Downloading file: 145 out of 200 ( XC735370-220320 Amsel Gesang FH 0417 0552 MP3.mp3 )
# Downloading file: 146 out of 200 ( XC735369-220320 Amsel Gesang FH 0417 0541 MP3.mp3 )
# Downloading file: 147 out of 200 ( XC735080-Turdus merula Eurasian Blackbird song 2022-06-18 1048 Kazachka, Karasay District 43.131453, 76.956170 (not seen) ME66-D100.wav.mp3 )
# Downloading file: 148 out of 200 ( XC735022-Koltrast_32.mp3 )
# Downloading file: 149 out of 200 ( XC734787-MVI_3844.mp3 )
# Downloading file: 150 out of 200 ( XC734785-MVI_3843.mp3 )
# Downloading file: 151 out of 200 ( XC734180-koltrast_20220626_0032_sång_Norra_Långsbo_AA_redigerad_202206.mp3 )
# Downloading file: 152 out of 200 ( XC733914-Common Blackbird_hunting lodge_DLY.mp3 )
# Downloading file: 153 out of 200 ( XC733043-MVI_4670.mp3 )
# Downloading file: 154 out of 200 ( XC732420-20220513_075710_Vergons_Crémon-Merlenoir_song+++.mp3 )
# Downloading file: 155 out of 200 ( XC732419-20220513_080800_Vergons_Crémon-merlenoir_song+++.mp3 )
# Downloading file: 156 out of 200 ( XC731985-amsel0457.mp3 )
# Downloading file: 157 out of 200 ( XC731077-merlo-parcheggio-Colonna.mp3 )
# Downloading file: 158 out of 200 ( XC729886-TURMER_220525_2242_Sers_Pau64.mp3 )
# Downloading file: 159 out of 200 ( XC729881-TURMER_220525_2225_Maharin_Anglet64.mp3 )
# Downloading file: 160 out of 200 ( XC729880-TURMER_220525_2216_Maharin_Anglet64.mp3 )
# Downloading file: 161 out of 200 ( XC729376-Amsel Frauenkirchen 20210522_172702.mp3 )
# Downloading file: 162 out of 200 ( XC728549-merlo-gressa.mp3 )
# Downloading file: 163 out of 200 ( XC728291-220522_0647 1750 Amsel. HR, Otok Pag, Vlasici. Stephan Risch.mp3 )
# Downloading file: 164 out of 200 ( XC728072-blackbird.mp3 )
# Downloading file: 165 out of 200 ( XC727130-Amsel 20h.mp3 )
# Downloading file: 166 out of 200 ( XC727129-Amsel 20h mit Kuckuck.mp3 )
# Downloading file: 167 out of 200 ( XC727127-Amsel 19h45.mp3 )
# Downloading file: 168 out of 200 ( XC727060-TURMER_220520_2174_Caudebec76.mp3 )
# Downloading file: 169 out of 200 ( XC727058-TURMER_220520_2178_Caudebec76.mp3 )
# Downloading file: 170 out of 200 ( XC727056-TURMER_220520_2182_Caudebec76.mp3 )
# Downloading file: 171 out of 200 ( XC727054-TURMER_220520_2172_Caudebec76.mp3 )
# Downloading file: 172 out of 200 ( XC726282-TURMER_FRICOE_220520_2115_Jumieges76.mp3 )
# Downloading file: 173 out of 200 ( XC726280-TURMER_220520_2133_Jumieges76.mp3 )
# Downloading file: 174 out of 200 ( XC726279-TURMER_220520_2114_Jumieges76.mp3 )
# Downloading file: 175 out of 200 ( XC725813-220420_04_10h25g_Merle_11h20.mp3 )
# Downloading file: 176 out of 200 ( XC725749-220513_53Turdus merula carrizo, 21.30 Castelo Monterrei, Verín.mp3 )
# Downloading file: 177 out of 200 ( XC725632-220419_06_17h30e_Merle_18h25.mp3 )
# Downloading file: 178 out of 200 ( XC725152-220516_22Merlo 9.30 Razosalgueiros.mp3 )
# Downloading file: 179 out of 200 ( XC724263-Blackbird .mp3 )
# Downloading file: 180 out of 200 ( XC724072-TURMER_220513_1981_Marcevol66.mp3 )
# Downloading file: 181 out of 200 ( XC723956-0430_041322a.mp3 )
# Downloading file: 182 out of 200 ( XC723766-Turdus merula_2022.05.12_11.13_01.MP3 )
# Downloading file: 183 out of 200 ( XC723106-220429_0496 1926 Amsel. B, Spandau Tiefenwerder Wiesen. Stephan Risch.mp3 )
# Downloading file: 184 out of 200 ( XC722741-220507_15 Turdus merula 12.30 Sarela, Vista Alegre, Santiago.mp3 )
# Downloading file: 185 out of 200 ( XC722327-220506_8889 tm 8892 Merel Groene kikker.mp3 )
# Downloading file: 186 out of 200 ( XC722155-Blackbird_Song_Mimicry of Grey Plover_Cahore_230422_A.mp3 )
# Downloading file: 187 out of 200 ( XC722117-220505_8721 Merel.mp3 )
# Downloading file: 188 out of 200 ( XC722047-mirlo los tilos.mp3 )
# Downloading file: 189 out of 200 ( XC722004-mirlo canarias.mp3 )
# Downloading file: 190 out of 200 ( XC721994-mirlo.mp3 )
# Downloading file: 191 out of 200 ( XC721872-Merle noir Song Kerhinet stlyphars may 4 1206_3551.mp3 )
# Downloading file: 192 out of 200 ( XC721489-R00252.mp3 )
# Downloading file: 193 out of 200 ( XC721091-Eurasian Blackbird 1.mp3 )
# Downloading file: 194 out of 200 ( XC720874-MVI_3670.mp3 )
# Downloading file: 195 out of 200 ( XC719695-Svarttrost XC Helgøya syd Elias A. Ryberg20220419152648_061.mp3 )
# Downloading file: 196 out of 200 ( XC719621-TURMER Laeva pt 13 220413_4016.mp3 )
# Downloading file: 197 out of 200 ( XC718750-turdus_merula_laskowiec_podlaskie_2022.04.23_1944.mp3 )
# Downloading file: 198 out of 200 ( XC718137-Merle noir song plelan le grand apr 24 1529_3332.mp3 )
# Downloading file: 199 out of 200 ( XC718135-Merle noir song plelan le grand apr 24 1537_3337.mp3 )
# Downloading file: 200 out of 200 ( XC717803-Blackbird_Song_Mimicry of RP_Lissagriffin_23+24.03.22_A.mp3 )
# Getting recordings data for Fringilla+coelebs with quality A
# Getting recordings data for Fringilla+coelebs with quality B
# Getting recordings data for Fringilla+coelebs with quality C
# Downloading file: 1 out of 200 ( XC795208-20230422_093540-zięba-eBird-do-xc.wav )
# Downloading file: 2 out of 200 ( XC795040-230404_26PImpín-call-and-song---10.00-AS-galegas,-Biobra.mp3 )
# Downloading file: 3 out of 200 ( XC795039-230404_22-Pimpín-pink-call-and-song-9.30-As-galegas,-Biobra,-Rubiá.mp3 )
# Downloading file: 4 out of 200 ( XC795038-230404_22-Pimpín-pink-call-and-song-9.30-As-galegas,-Biobra,-Rubiá.mp3 )
# Downloading file: 5 out of 200 ( XC795035-230404_02Pimpín-bo-callandsong-9.00-Biobra,-Rubiá.mp3 )
# Downloading file: 6 out of 200 ( XC794236-pinson.mp3 )
# Downloading file: 7 out of 200 ( XC794200-FricoeTop2_Santo-António.wav )
# Downloading file: 8 out of 200 ( XC794199-Fricoetop1_Santo-António.wav )
# Downloading file: 9 out of 200 ( XC794184-Fringilla-coelebstopinho1_Poços.wav )
# Downloading file: 10 out of 200 ( XC794183-Fringilla-coelebsTop1_Poços.wav )
# Downloading file: 11 out of 200 ( XC794181-Fringilla-coelebs2_Poços.wav )
# Downloading file: 12 out of 200 ( XC794042-Bofink_24.mp3 )
# Downloading file: 13 out of 200 ( XC794012-Fricoe2_Jardim-Botânico-de-Pedro-Miguel.wav )
# Downloading file: 14 out of 200 ( XC794011-Fricoe1_Jardim-Botânico-de-Pedro-Miguel.wav )
# Downloading file: 15 out of 200 ( XC793830-fcoelebs_230415_jablonove.wav )
# Downloading file: 16 out of 200 ( XC793618-Bofink_23.mp3 )
# Downloading file: 17 out of 200 ( XC793409-JAREK-MATUSIAK-A-1973-(2.1)-zięba.mp3 )
# Downloading file: 18 out of 200 ( XC793363-BOFINK_230409_003_Tr1.mp3 )
# Downloading file: 19 out of 200 ( XC793278-Bofink_22.mp3 )
# Downloading file: 20 out of 200 ( XC793237-230413_1595-1638-Buchfink.-CZ,-Becov-nad-Teplou.-Stephan-Risch.wav )
# Downloading file: 21 out of 200 ( XC792875-Fricoe.1.Pico-Gaspar.wav )
# Downloading file: 22 out of 200 ( XC792863-Fricoe1_Catarina-Vieira.wav )
# Downloading file: 23 out of 200 ( XC792862-Fricoe-&-Sercan1_Catarina-Vieira.wav )
# Downloading file: 24 out of 200 ( XC792717-FRICOE_230329_2547_Paimpont35_SBP.mp3 )
# Downloading file: 25 out of 200 ( XC792675-T51.mp3 )
# Downloading file: 26 out of 200 ( XC792603-090423-beas-fingrilla-coellebs-9-18.wav )
# Downloading file: 27 out of 200 ( XC792258-F.-coelebs-230406,-д.-Сойгино,-р.-Бездна,-AAB-song.mp3 )
# Downloading file: 28 out of 200 ( XC792231-230407_24Fringilla-coelebs-12.00-Brandomil,-Zas.mp3 )
# Downloading file: 29 out of 200 ( XC792138-Chaffinch-song.mp3 )
# Downloading file: 30 out of 200 ( XC792114-fcoelebs_230409_prepadle.wav )
# Downloading file: 31 out of 200 ( XC792105-20230410_110242-fringuello-palazzi.mp3 )
# Downloading file: 32 out of 200 ( XC791597-Fricoe3_ARegatos.wav )
# Downloading file: 33 out of 200 ( XC791596-Fricoe2_ARegatos.wav )
# Downloading file: 34 out of 200 ( XC791594-Fricoe1_ARegatos.wav )
# Downloading file: 35 out of 200 ( XC791372-220605_010_Tr1.mp3 )
# Downloading file: 36 out of 200 ( XC791364-Fricoe3_Lagoa-das-Narcejas.wav )
# Downloading file: 37 out of 200 ( XC791362-Fricoe2_Lagoa-das-Narcejas.wav )
# Downloading file: 38 out of 200 ( XC791361-Fricoe1_Lagoa-das-Narcejas.wav )
# Downloading file: 39 out of 200 ( XC791315-220604_007_Tr1.mp3 )
# Downloading file: 40 out of 200 ( XC791314-220604_006_Tr1.mp3 )
# Downloading file: 41 out of 200 ( XC791307-220604_002_Tr1.mp3 )
# Downloading file: 42 out of 200 ( XC791287-220531_012_Tr1.mp3 )
# Downloading file: 43 out of 200 ( XC791192-Bofink_20.mp3 )
# Downloading file: 44 out of 200 ( XC791135-Fringilla-coelebstop2_Pau-Velho.wav )
# Downloading file: 45 out of 200 ( XC791132-Fringilla-coelebstop1_Pau-Velho.wav )
# Downloading file: 46 out of 200 ( XC790663-Fricoetop4_Lagoa-do-Caiado.wav )
# Downloading file: 47 out of 200 ( XC790661-Fricoetop3_Lagoa-do-Capitão.wav )
# Downloading file: 48 out of 200 ( XC790660-Fricoetop2_Lagoa-do-Capitão.wav )
# Downloading file: 49 out of 200 ( XC790659-Fricoetop1_Lagoa-do-Capitão.wav )
# Downloading file: 50 out of 200 ( XC790656-Fricoetop3_Lagoa-do-Landroal.wav )
# Downloading file: 51 out of 200 ( XC790655-Fricoetop2_Lagoa-do-Landroal.wav )
# Downloading file: 52 out of 200 ( XC790654-Fricoetop1Lagoa-do-Landroal.wav )
# Downloading file: 53 out of 200 ( XC790516-FRICOE_220314_6545_Marcevol66.mp3 )
# Downloading file: 54 out of 200 ( XC790415-Bofink_19.mp3 )
# Downloading file: 55 out of 200 ( XC790345-FRICOE_220327_1481_AireFenioux.mp3 )
# Downloading file: 56 out of 200 ( XC789873-220510_004_Tr1.mp3 )
# Downloading file: 57 out of 200 ( XC789863-220503_016_Tr1.mp3 )
# Downloading file: 58 out of 200 ( XC789857-220503_013_Tr1.mp3 )
# Downloading file: 59 out of 200 ( XC789846-220503_003_Tr1.mp3 )
# Downloading file: 60 out of 200 ( XC789845-220503_002_Tr1.mp3 )
# Downloading file: 61 out of 200 ( XC789650-2022_april_02_vink_1556hrs_Montfrague_GOKeijl.mp3 )
# Downloading file: 62 out of 200 ( XC788970-CH.8201D51.wav )
# Downloading file: 63 out of 200 ( XC788733-Fringilla-coelebs_2023.03.24_15.40_01.mp3 )
# Downloading file: 64 out of 200 ( XC788625-FRICOE_230327_2519_Rocher_Cadieu35.mp3 )
# Downloading file: 65 out of 200 ( XC788622-FRICOE_230327_2519_Rocher_Cadieu35.mp3 )
# Downloading file: 66 out of 200 ( XC788424-230323_0957Fricoe.mp3 )
# Downloading file: 67 out of 200 ( XC788117-220501_014_Tr1.mp3 )
# Downloading file: 68 out of 200 ( XC787302-220430_011_Tr1.mp3 )
# Downloading file: 69 out of 200 ( XC786919-vinkenzang3.mp3 )
# Downloading file: 70 out of 200 ( XC786915-vinkenzang.mp3 )
# Downloading file: 71 out of 200 ( XC786657-2023-03-19-CH-clip.wav )
# Downloading file: 72 out of 200 ( XC785700-Pinson_des_arbres_2022-04-14_11-08-00.mp3 )
# Downloading file: 73 out of 200 ( XC785351-vink_zang_drongengoedbos_B.mp3 )
# Downloading file: 74 out of 200 ( XC785068-20230309_155616-zięba-eBird.wav )
# Downloading file: 75 out of 200 ( XC784537-Fringilla-coelebs_2023.03.03_10.29_024.mp3 )
# Downloading file: 76 out of 200 ( XC783979-birdnet_mobile_0829053260_recording_708.wav )
# Downloading file: 77 out of 200 ( XC782708-chaffinchsongtacfeb23.wav )
# Downloading file: 78 out of 200 ( XC782613-Fringilla-coelebs_2023.02.21_10.40_013.mp3 )
# Downloading file: 79 out of 200 ( XC781991-chaffinchsongtacfeb23.wav )
# Downloading file: 80 out of 200 ( XC779748-230211_001.mp3 )
# Downloading file: 81 out of 200 ( XC779452-Bogfinke-(Fringilla-coelebs)-Topbjerg_20200321-1629-sang.mp3 )
# Downloading file: 82 out of 200 ( XC778066-STE-031détail.mp3 )
# Downloading file: 83 out of 200 ( XC770163-Vink-zang---Monfrague---2019-01-16---1118-copy.mp3 )
# Downloading file: 84 out of 200 ( XC770162-Vink-zang---Monfrague---2019-01-16---1053-copy.mp3 )
# Downloading file: 85 out of 200 ( XC770105-Vink-zang---Zeewolde---2022-06-05---0836-copy.mp3 )
# Downloading file: 86 out of 200 ( XC769686-Vink-zang---Nijkerk---2022-06-05---0725-copy.mp3 )
# Downloading file: 87 out of 200 ( XC768333-chaffinch.mp3 )
# Downloading file: 88 out of 200 ( XC764893-170519_08A-Bofink.mp3 )
# Downloading file: 89 out of 200 ( XC764784-180508_02A-sel-Bofink.mp3 )
# Downloading file: 90 out of 200 ( XC762230-S4A10708_20190516_9.30_F.coel-śp.mp3 )
# Downloading file: 91 out of 200 ( XC758892-221101_03Pimpín-8.30-call-and-song-Sisalde-río.mp3 )
# Downloading file: 92 out of 200 ( XC758601-220702_11Pimpín-3-tipos-de-calls-9.30-Pontearnelas.mp3 )
# Downloading file: 93 out of 200 ( XC758399-xc-wa013525-000015.mp3 )
# Downloading file: 94 out of 200 ( XC757015-Chaffinch_rain-call_20210602_203502_prepared.mp3 )
# Downloading file: 95 out of 200 ( XC744879-220726_Common Chaffinch_2_song_Senatta area_TC_OC.mp3 )
# Downloading file: 96 out of 200 ( XC744874-220726_Common Chaffinch_song_TC_OC.mp3 )
# Downloading file: 97 out of 200 ( XC741704-9.mp3 )
# Downloading file: 98 out of 200 ( XC741276-Bofink_18.mp3 )
# Downloading file: 99 out of 200 ( XC740217-DM-_20220623_060259-7.00_Frin.coel.mp3 )
# Downloading file: 100 out of 200 ( XC739327-DM-_20220622_190000-19.00_F.coel_GS.mp3 )
# Downloading file: 101 out of 200 ( XC738954-LS_50337_08h10c.mp3 )
# Downloading file: 102 out of 200 ( XC735816-Chaffinch_Song_Inchadoney_030622_A+.mp3 )
# Downloading file: 103 out of 200 ( XC735686-buchfink0445.mp3 )
# Downloading file: 104 out of 200 ( XC735006-Chaffinch_Song_Portlick_280522_A+.mp3 )
# Downloading file: 105 out of 200 ( XC735005-Chaffinch_Double Rain Song_Lough Owell_290522_A+++.mp3 )
# Downloading file: 106 out of 200 ( XC735004-Chaffinch_Double Rain Song_Lough Owell_290522_A.mp3 )
# Downloading file: 107 out of 200 ( XC734962-Chaffinch_Song_Boora Bog_280522_F6_A++++.mp3 )
# Downloading file: 108 out of 200 ( XC734918-22-6-29 vink overheide (1).mp3 )
# Downloading file: 109 out of 200 ( XC734900-Chaffinch_Abbasabad_DLY.mp3 )
# Downloading file: 110 out of 200 ( XC734560-220504_CommonChaffinch_2_song_BorjomiNP_HQ trail_OC.mp3 )
# Downloading file: 111 out of 200 ( XC734559-220504_CommonChaffinch_1_song_BorjomiNP_HQ trail_OC.mp3 )
# Downloading file: 112 out of 200 ( XC734327-Fringuello song_0622_1118.mp3 )
# Downloading file: 113 out of 200 ( XC733984-FRICOE2022-05-24-06-18-20-PAINUA-s-A.mp3 )
# Downloading file: 114 out of 200 ( XC733821-zięba i sosnowka 220422_Jastrzębia.mp3 )
# Downloading file: 115 out of 200 ( XC733685-Common Chaffinch - Pagham - F3+TTS - 220517-01F.mp3 )
# Downloading file: 116 out of 200 ( XC732751-0430_022812a.mp3 )
# Downloading file: 117 out of 200 ( XC732733-buchfink0434.mp3 )
# Downloading file: 118 out of 200 ( XC732137-Common Chaffinch (song, BE, Elsenborn, 210626_003).mp3 )
# Downloading file: 119 out of 200 ( XC731870-2022.06.12_10.32_01.MP3 )
# Downloading file: 120 out of 200 ( XC731362-220609_24Pimpín raro 20.00 Bodeira Ogrove.mp3 )
# Downloading file: 121 out of 200 ( XC730707-ZOOM0009 BOFIN S lunden 2022-06-10.mp3 )
# Downloading file: 122 out of 200 ( XC728624-Fringilla coelebs_2022.05.31_09.02_01.MP3 )
# Downloading file: 123 out of 200 ( XC728596-Fri.coe Tuzla 220508_0365.mp3 )
# Downloading file: 124 out of 200 ( XC727598-Fringilla coelebs Common Chaffinch song 2022-05-11 1011 Emine Hills, Nesebar 42.70648, 27.88432 (seen) ME66-D100.mp3 )
# Downloading file: 125 out of 200 ( XC727214-FRICOE_220520_2153_culdeSac76.mp3 )
# Downloading file: 126 out of 200 ( XC727213-FRICOE_220520_2152_B918_CuldeSac76.mp3 )
# Downloading file: 127 out of 200 ( XC726874-Mönchsgrasmücke.mp3 )
# Downloading file: 128 out of 200 ( XC726758-220524_05Fringilla coelebs 2 tipos de versos 11.00 Francos, Teo.mp3 )
# Downloading file: 129 out of 200 ( XC726686-Default_20220525-bofink.mp3 )
# Downloading file: 130 out of 200 ( XC726550-pinzon.mp3 )
# Downloading file: 131 out of 200 ( XC726375-FRICOE_220516_2020_Grimbouville27.mp3 )
# Downloading file: 132 out of 200 ( XC725778-220513_16 Pimpín en rebolo 17.00 Mourazos-Tamaguelos, Oímbra.mp3 )
# Downloading file: 133 out of 200 ( XC725773-220513_06Pimpín 16.30 Mourozos- Tamaguelos, Oimbra.mp3 )
# Downloading file: 134 out of 200 ( XC723052-Chaffinch_Song_Donaghmore - Wexford_260422_A+++.mp3 )
# Downloading file: 135 out of 200 ( XC722736-220507_02 Pimpín,  11.00 Sarela, Vista alegre, Santiago.mp3 )
# Downloading file: 136 out of 200 ( XC722057-Pinson des arbres song la chapelle may 5 820_3558.mp3 )
# Downloading file: 137 out of 200 ( XC722056-Pinson des arbres song la chapelle sur erdre may 5 821_3559.mp3 )
# Downloading file: 138 out of 200 ( XC722054-Pinson des arbres song la chapelle sur erdre may 5 823_3561.mp3 )
# Downloading file: 139 out of 200 ( XC722053-Pinson des arbres song la chapelle sur erdre may 5 844_3563.mp3 )
# Downloading file: 140 out of 200 ( XC721899-0011Pinson des arbres.mp3 )
# Downloading file: 141 out of 200 ( XC720832-Pinson_des_arbres_14-04-2022_Le-Croisic_cris_femelle+male+accouplement.mp3 )
# Downloading file: 142 out of 200 ( XC720709-Fringuello song_0428_1855.mp3 )
# Downloading file: 143 out of 200 ( XC720171-Pinson des arbres song st mars du desert apr 28 1234_3454.mp3 )
# Downloading file: 144 out of 200 ( XC719878-27042022_FRICOE.mp3 )
# Downloading file: 145 out of 200 ( XC718722-FRICOE VBO 220415_4036.mp3 )
# Downloading file: 146 out of 200 ( XC718140-FRICOE_220423_1773_Monteneuf85.mp3 )
# Downloading file: 147 out of 200 ( XC717698-Chaffinch_Rain Song+ Calls + Song_Rostellan Wood_30.03.22_A.mp3 )
# Downloading file: 148 out of 200 ( XC717558-Common Chaffinch Song_01.mp3 )
# Downloading file: 149 out of 200 ( XC717190-220416_14 Pimpín As Gándaras, 10.30 Cambados.mp3 )
# Downloading file: 150 out of 200 ( XC717187-Fringuello song_0420_1917.mp3 )
# Downloading file: 151 out of 200 ( XC717157-JAREK-MATUSIAK-A-1746 (2) zięba2.mp3 )
# Downloading file: 152 out of 200 ( XC717153-JAREK-MATUSIAK-A-1746 (2) zięba.mp3 )
# Downloading file: 153 out of 200 ( XC717086-Pinson des arbres la chapelle april 21 1046_3280.mp3 )
# Downloading file: 154 out of 200 ( XC717081-Pinson des arbres la chapelle song apr 21 1101_3286.mp3 )
# Downloading file: 155 out of 200 ( XC717071-Pinson des arbres song la chapelle apr 21 1139_3299.mp3 )
# Downloading file: 156 out of 200 ( XC717070-Pinson des arbres song la chapelle apr 21 1142_3300.mp3 )
# Downloading file: 157 out of 200 ( XC716878-Vink, zang, Eder Heide, defensieterrein, 190422, 0853 uur.mp3 )
# Downloading file: 158 out of 200 ( XC716877-Vink, zang, Eder Heide, defensieterrein, 190422, 0856 uur.mp3 )
# Downloading file: 159 out of 200 ( XC716518-220415_0613_Pinson des arbres(chant)_Coudray.mp3 )
# Downloading file: 160 out of 200 ( XC715875-buchf0726.mp3 )
# Downloading file: 161 out of 200 ( XC715537-bofink_20220415_0536_sång_avvikande_Norra_Långsbo_AA_redigerad_202204.mp3 )
# Downloading file: 162 out of 200 ( XC715483-bofink_20220414_1011_sång_Norra_Långsbo_AA_redigerad_202204.mp3 )
# Downloading file: 163 out of 200 ( XC715479-Buchfink_Gesang_Kanadaskogen_140422.mp3 )
# Downloading file: 164 out of 200 ( XC714550-Fringuello song_0410_1123.mp3 )
# Downloading file: 165 out of 200 ( XC714548-Fringuello song_0409_1908.mp3 )
# Downloading file: 166 out of 200 ( XC714251-zięba 220409_Psary.mp3 )
# Downloading file: 167 out of 200 ( XC714147-20220409_0706_Buchfink_Hägendorf_630385_243158_song_call.mp3 )
# Downloading file: 168 out of 200 ( XC713698-zięba64.mp3 )
# ...
# splitting recording 52 A_XC779539-KOHLMEISEN,-Gesang--9_25--IMG_-230204-3460-g.wav out of 200 for bird Parus_major
# splitting recording 53 A_XC770768-Koolmees-zang---Bodegraven---2020-05-03---0550-copy.mp3 out of 200 for bird Parus_major
Mésange-charbonnière-mâle-Chaussins-8-mars-2023-type-rapide.mp3 out of 200 for bird Parus_major
# splitting recording 195 A_XC778471-greattittacjan23.wav out of 200 for bird Parus_major
# splitting recording 196 A_XC794645-MVI_5842.mp3 out of 200 for bird Parus_major
# splitting recording 197 A_XC732025-Tit_Great2_SDMKH-368_EdensGardenForestEdge_Dawn_6thJune22.mp3 out of 200 for bird Parus_major
# splitting recording 198 A_XC777118-180506_1339-0930-Mammendorf_NNP_Great-Tit.wav out of 200 for bird Parus_major
# splitting recording 199 A_XC737812-1122 Koolmeeszang coolhem.mp3 out of 200 for bird Parus_major
# splitting recording 200 A_XC783299-Parus-Major_2023.01.19_09.50_02.mp3 out of 200 for bird Parus_major

# %% [markdown]
# ## Création des jeux de données

# %%
# create train, test and text pointers
recordings_folder = "recordings"
main_bird = "Parus major"

file_name = "testing_list.txt"

count = 0
with open(os.path.join(recordings_folder, file_name), "w", encoding="utf-8") as f:
    for bird_type in os.listdir(recordings_folder):
        bird_folder = os.path.join(recordings_folder, bird_type)
        if os.path.isdir(bird_folder):
            for recording in os.listdir(bird_folder):
                sound_filename = os.path.join(bird_folder, recording)
                if os.path.isfile(sound_filename) and "splitted_" in sound_filename:
                  if count < 1000:
                        if np.random.rand() > 0.3:
                            f.write(sound_filename + "\n")
                            count += 1
            count = 0
print("Done")
# Out:
# Done

# %% [markdown]
# ## Création des jeux de données

# %%
dataset_dir = Path('recordings')

CLASSES = ["Parus_major", "Turdus_merula", "Fringilla_coelebs"]

with (dataset_dir/ 'testing_list.txt').open(encoding='utf-8') as f:
    testing_list = f.read().splitlines()

x_train = []
y_train = []
x_test = []
y_test = []

for recording in dataset_dir.glob('**/*.wav'):
    if not recording.parent.name in CLASSES:
        continue
    if "splitted_" not in str(recording):
        continue
    label = CLASSES.index(recording.parent.name)

    with wave.open(str(recording)) as f :
        data = np.frombuffer(f.readframes(f.getnframes()), dtype=np.int16).copy()

    data = data.astype(np.float32)
    data.resize((16000, 1))

    if "splitted_" in str(recording):
        if str(recording) in testing_list:
            x_test.append(data)
            y_test.append(label)
        elif y_train.count(label) < 2400:
            x_train.append(data)
            y_train.append(label)

x_train = np.array(x_train)
y_train = to_categorical(np.array(y_train))
x_test = np.array(x_test)
y_test = to_categorical(np.array(y_test))

# %%
print(x_test.shape)
print(y_test.shape)
print(x_train.shape)
print(y_train.shape)
# Out:
# (3000, 16000, 1)
# (3000, 3)
# (7200, 16000, 1)
# (7200, 3)

# %%
unique_labels, label_counts = np.unique(y_train, return_counts=True)
for label, count in zip(unique_labels, label_counts):
    print(f"Label {label}: {count} occurrences")

# %% [markdown]
# ## Normalize data

# %%
x_mean = x_train.mean()
x_std = x_train.std()

x_train -= x_mean
x_test -= x_mean
x_train /= x_std
x_test /= x_std

# %% [markdown]
# ## Exporter les données

# %%
np.savetxt('x_test.csv', x_test.reshape(x_test.shape[0], -1), delimiter=',', fmt='%s')
np.savetxt('y_test.csv', y_test, delimiter=',', fmt='%s')

# %% [markdown]
# ## Build model M5

# %%
# Modifier

model = Sequential()
model.add(Input(shape=(16000, 1)))
model.add(MaxPool1D(pool_size=20, padding='valid'))
model.add(Conv1D(filters=8, kernel_size=40, activation='relu'))
model.add(MaxPool1D(pool_size=4, padding='valid'))
model.add(Conv1D(filters=16, kernel_size=3, activation='relu'))
model.add(MaxPool1D(pool_size=4, padding='valid'))
model.add(Conv1D(filters=32, kernel_size=3, activation='relu'))
model.add(MaxPool1D(pool_size=4, padding='valid'))
model.add(AvgPool1D(pool_size=8))
model.add(Flatten())
model.add(Dense(units=3))
model.add(Activation('softmax'))  # SoftMax activation needs to be separate from Dense to remove it later on
# EXPLORE Learning Rate
opt = tf.keras.optimizers.Adam(learning_rate=10e-4)
model.summary()
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
# Out:
# Model: "sequential_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  max_pooling1d_60 (MaxPoolin  (None, 800, 1)           0
#  g1D)
#
#  conv1d_45 (Conv1D)          (None, 761, 8)            328
#
#  max_pooling1d_61 (MaxPoolin  (None, 190, 8)           0
#  g1D)
#
#  conv1d_46 (Conv1D)          (None, 188, 16)           400
#
#  max_pooling1d_62 (MaxPoolin  (None, 47, 16)           0
#  g1D)
#
#  conv1d_47 (Conv1D)          (None, 45, 32)            1568
#
#  max_pooling1d_63 (MaxPoolin  (None, 11, 32)           0
#  g1D)
#
#  average_pooling1d_15 (Avera  (None, 1, 32)            0
#  gePooling1D)
#
#  flatten_15 (Flatten)        (None, 32)                0
#
#  dense_15 (Dense)            (None, 3)                 99
#
#  activation_15 (Activation)  (None, 3)                 0
#
# =================================================================
# Total params: 2,395
# Trainable params: 2,395
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Train model

# %%
model.fit(x_train, y_train, epochs=5, batch_size=100, validation_data=(x_test, y_test))
# Out:
# Epoch 1/5
# 72/72 [==============================] - 3s 19ms/step - loss: 1.0965 - categorical_accuracy: 0.3569 - val_loss: 1.0897 - val_categorical_accuracy: 0.3783
# Epoch 2/5
# 72/72 [==============================] - 1s 9ms/step - loss: 1.0813 - categorical_accuracy: 0.4014 - val_loss: 1.0776 - val_categorical_accuracy: 0.3947
# Epoch 3/5
# 72/72 [==============================] - 1s 9ms/step - loss: 1.0690 - categorical_accuracy: 0.4238 - val_loss: 1.0920 - val_categorical_accuracy: 0.4063
# Epoch 4/5
# 72/72 [==============================] - 1s 10ms/step - loss: 1.0573 - categorical_accuracy: 0.4500 - val_loss: 1.0580 - val_categorical_accuracy: 0.4480
# Epoch 5/5
# 72/72 [==============================] - 1s 12ms/step - loss: 1.0513 - categorical_accuracy: 0.4607 - val_loss: 1.0528 - val_categorical_accuracy: 0.4397

# %% [markdown]
# ## Evaluate model on test dataset

# %%
model.evaluate(x_test, y_test, verbose=2)
pred_test = model.predict(x_test)
print(tf.math.confusion_matrix(y_test.argmax(axis=1), pred_test.argmax(axis=1)))
# Out:
# 94/94 - 1s - loss: 1.0528 - categorical_accuracy: 0.4397 - 1s/epoch - 11ms/step
# 94/94 [==============================] - 1s 5ms/step
# tf.Tensor(
# [[577  67 356]
#  [396 167 437]
#  [324 101 575]], shape=(3, 3), dtype=int32)

# %% [markdown]
# ## Save trained model

# %%
model.save('lab_gsc.h5')
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %% [markdown]
# ## Remove SoftMax layer

# %%
model = tf.keras.Model(model.input, model.layers[-2].output, name=model.name)

# %% [markdown]
# ## Install MicroAI for C inference code generation (kerascnn2c module)

# %%
# !pip install https://bitbucket.org/edge-team-leat/microai_public/get/6adfbcb347d3.zip#subdirectory=third_party/kerascnn2c_fixed
import kerascnn2c
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting https://bitbucket.org/edge-team-leat/microai_public/get/6adfbcb347d3.zip#subdirectory=third_party/kerascnn2c_fixed
#   Downloading https://bitbucket.org/edge-team-leat/microai_public/get/6adfbcb347d3.zip (1.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 2.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from kerascnn2c==1.0.0) (1.22.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from kerascnn2c==1.0.0) (3.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->kerascnn2c==1.0.0) (2.1.2)

# %% [markdown]
# ## Generate C code for the trained model with 16-bit fixed-point representation

# %%
res = kerascnn2c.Converter(output_path=Path('gsc_output_fixed'),
                           fixed_point=9, # Number of bits for the fractional part, Q7.9 format
                           number_type='int16_t', # Data type for weights/activations (16 bits quantization)
                           long_number_type='int32_t', # Data type for intermediate results
                           number_min=-(2**15), # Minimum value for 16-bit signed integers
                           number_max=(2**15)-1 # Maximum value for 16-bit signed integers
                          ).convert_model(copy.deepcopy(model))
with open('gsc_model_fixed.h', 'w') as f:
    f.write(res)
# Out:
# ———————————————————————————————————————————————————————————————————————————————————————————————————————
# Inputs                           | Layer                            | Outputs
# ———————————————————————————————————————————————————————————————————————————————————————————————————————
#                                  | input_16                         | max_pooling1d_60
# -------------------------------------------------------------------------------------------------------
# input_16                         | max_pooling1d_60                 | conv1d_45
# -------------------------------------------------------------------------------------------------------
# max_pooling1d_60                 | conv1d_45                        | max_pooling1d_61
# -------------------------------------------------------------------------------------------------------
# conv1d_45                        | max_pooling1d_61                 | conv1d_46
# -------------------------------------------------------------------------------------------------------
# max_pooling1d_61                 | conv1d_46                        | max_pooling1d_62
# -------------------------------------------------------------------------------------------------------
# conv1d_46                        | max_pooling1d_62                 | conv1d_47
# -------------------------------------------------------------------------------------------------------
# max_pooling1d_62                 | conv1d_47                        | max_pooling1d_63
# -------------------------------------------------------------------------------------------------------
# conv1d_47                        | max_pooling1d_63                 | average_pooling1d_15
# -------------------------------------------------------------------------------------------------------
# max_pooling1d_63                 | average_pooling1d_15             | flatten_15
# -------------------------------------------------------------------------------------------------------
# average_pooling1d_15             | flatten_15                       | dense_15
# -------------------------------------------------------------------------------------------------------
# flatten_15                       | dense_15                         |
# -------------------------------------------------------------------------------------------------------
#
# After optimization:
# ———————————————————————————————————————————————————————————————————————————————————————————————————————
# Inputs                           | Layer                            | Outputs
# ———————————————————————————————————————————————————————————————————————————————————————————————————————
#                                  | input_16                         | max_pooling1d_60
# -------------------------------------------------------------------------------------------------------
# input_16                         | max_pooling1d_60                 | conv1d_45
# -------------------------------------------------------------------------------------------------------
# max_pooling1d_60                 | conv1d_45                        | max_pooling1d_61
# -------------------------------------------------------------------------------------------------------
# conv1d_45                        | max_pooling1d_61                 | conv1d_46
# -------------------------------------------------------------------------------------------------------
# max_pooling1d_61                 | conv1d_46                        | max_pooling1d_62
# -------------------------------------------------------------------------------------------------------
# conv1d_46                        | max_pooling1d_62                 | conv1d_47
# -------------------------------------------------------------------------------------------------------
# max_pooling1d_62                 | conv1d_47                        | max_pooling1d_63
# -------------------------------------------------------------------------------------------------------
# conv1d_47                        | max_pooling1d_63                 | average_pooling1d_15
# -------------------------------------------------------------------------------------------------------
# max_pooling1d_63                 | average_pooling1d_15             | flatten_15
# -------------------------------------------------------------------------------------------------------
# average_pooling1d_15             | flatten_15                       | dense_15
# -------------------------------------------------------------------------------------------------------
# flatten_15                       | dense_15                         |
# -------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Compile the 16-bit fixed-point C code for x86 and evaluate on small dataset

# %%
# !g++ -Wall -Wextra -pedantic -Ofast -o gsc_fixed -Igsc_output_fixed/ gsc_output_fixed/model.c main.cpp
# !./gsc_fixed x_test_gsc_250.csv y_test_gsc_250.csv
# Out:
# gsc_output_fixed/model.c: In function â€˜void cnn(const number_t (*)[16000], number_t*)â€™:
# gsc_output_fixed/model.c:114:18: warning: left operand of comma operator has no effect [-Wunused-value]
#   114 |     activations2.max_pooling1d_68_output,
#       |     ~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~
# cc1plus: fatal error: main.cpp: No such file or directory
# compilation terminated.
# '.' n'est pas reconnu en tant que commande interne
# ou externe, un programme ex‚cutable ou un fichier de commandes.
